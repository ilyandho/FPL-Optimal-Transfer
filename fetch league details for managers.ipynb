# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyandho/FPL-Optimal-Transfer/blob/main/fetch%20league%20details%20for%20managers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd
import math

base_url = 'https://fantasy.premierleague.com/api/'


def get_transfers(league):
    # Get manager details
    general_info = requests.get(base_url + "leagues-h2h-matches/league/" + str(league) + "/").json()

    # For each manager id, get the the details
    # for id_ in manager_ids:
    manager_details_ = [{"manager_id": manager['entry_1_entry'], "player_name": manager['entry_1_player_name'],
                         "name": manager['entry_1_name']} for manager in general_info['results']]
    manager_details = list(
        {manager['manager_id']: manager for manager in manager_details_}.values())

    # For each manager, get their pick history
    manager_picks = []
    for manager in manager_details:
        # For leagues with teams, a virtual manager is include.
        # Check if a manager_id is 'None' and skip that manager
        if (manager['manager_id'] == None):
            continue

        picks = []
        for gw in range(1, 39):
            try:
                gw_picks = requests.get(base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(gw) + "/picks/").json()
            except requests.exceptions.JSONDecodeError as jsonerror:
                print("JSONEconding Error: ", jsonerror, ", ",
                      gw, '=========> ', manager['manager_id'])
            except requests.exceptions.HTTPError as errh:
                print("Http Error:", errh)
            except requests.exceptions.ConnectionError as errc:
                print("Error Connecting:", errc)
            except requests.exceptions.Timeout as errt:
                print("Timeout Error:", errt)
            except requests.exceptions.RequestException as err:
                print("OOps: Something Else", err)

        picks = []
        for gw in range(1, 39):
            gw_picks = requests.get(base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        manager_picks.append({manager['manager_id']: picks})

    return {league: manager_picks}

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[0 : 310]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.1.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.1.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  246407
# Finished working on  246407
# Starting to work on  468584
# Finished working on  468584
# Starting to work on  14437
# Finished working on  14437
# Starting to work on  30826
# Finished working on  30826
# Starting to work on  92314
# Finished working on  92314
# Starting to work on  24476
# Finished working on  24476
# Starting to work on  1733762
# Finished working on  1733762
# Starting to work on  150
# Finished working on  150
# Starting to work on  176750
# Finished working on  176750
# Starting to work on  11921
# Finished working on  11921
# Starting to work on  412316
# Finished working on  412316
# Starting to work on  450092
# Finished working on  450092
# Starting to work on  296337
# Finished working on  296337
# Starting to work on  1443
# Finished working on  1443
# Starting to work on  390908
# Finished working on  390908
# Starting to work on  246044
# Finished working on  246044
# Starting to work on  3237821
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[310: 620]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.2.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.2.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  3114701
# Finished working on  3114701
# Starting to work on  266859
# Finished working on  266859
# Starting to work on  10116
# Finished working on  10116
# Starting to work on  200578
# Finished working on  200578
# Starting to work on  2666154
# Finished working on  2666154
# Starting to work on  6334189
# Finished working on  6334189
# Starting to work on  6714441
# Finished working on  6714441
# Starting to work on  6742332
# Finished working on  6742332
# Starting to work on  33899
# Finished working on  33899
# Starting to work on  190549
# Finished working on  190549
# Starting to work on  2252175
# Finished working on  2252175
# Starting to work on  6511112
# Finished working on  6511112
# Starting to work on  17574
# Finished working on  17574
# Starting to work on  39887
# Finished working on  39887
# Starting to work on  197346
# Finished working on  197346
# Starting to work on  3593
# Finished working on  3593
# Starting to work on  14731
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[620: 930]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.3.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.3.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  6237878
# Finished working on  6237878
# Starting to work on  87367
# Finished working on  87367
# Starting to work on  2818044
# Finished working on  2818044
# Starting to work on  482
# Finished working on  482
# Starting to work on  2774244
# Finished working on  2774244
# Starting to work on  4598218
# Finished working on  4598218
# Starting to work on  144963
# Finished working on  144963
# Starting to work on  120581
# Finished working on  120581
# Starting to work on  9959
# Finished working on  9959
# Starting to work on  1052576
# Finished working on  1052576
# Starting to work on  6560725
# Finished working on  6560725
# Starting to work on  59839
# Finished working on  59839
# Starting to work on  3411244
# Finished working on  3411244
# Starting to work on  552223
# Finished working on  552223
# Starting to work on  2696095
# Finished working on  2696095
# Starting to work on  3499851
# Finished working on  3499851
# Starting to work on  15034
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[930: 1240]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.4.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.4.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  758432
# Finished working on  758432
# Starting to work on  4100
# Finished working on  4100
# Starting to work on  103307
# Finished working on  103307
# Starting to work on  334580
# Finished working on  334580
# Starting to work on  875467
# Finished working on  875467
# Starting to work on  968634
# Finished working on  968634
# Starting to work on  264254
# Finished working on  264254
# Starting to work on  299
# Finished working on  299
# Starting to work on  3664358
# Finished working on  3664358
# Starting to work on  7808
# Finished working on  7808
# Starting to work on  264303
# Finished working on  264303
# Starting to work on  195225
# Finished working on  195225
# Starting to work on  25234
# Finished working on  25234
# Starting to work on  1219274
# Finished working on  1219274
# Starting to work on  482754
# Finished working on  482754
# Starting to work on  491020
# Finished working on  491020
# Starting to work on  3992841
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[1240: 1550]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.5.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.5.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  391855
# Finished working on  391855
# Starting to work on  19990
# Finished working on  19990
# Starting to work on  2501267
# Finished working on  2501267
# Starting to work on  733568
# Finished working on  733568
# Starting to work on  63807
# Finished working on  63807
# Starting to work on  1835125
# Finished working on  1835125
# Starting to work on  2881
# Finished working on  2881
# Starting to work on  10355
# Finished working on  10355
# Starting to work on  6036
# Finished working on  6036
# Starting to work on  375809
# Finished working on  375809
# Starting to work on  4071219
# Finished working on  4071219
# Starting to work on  660062
# Finished working on  660062
# Starting to work on  15558
# Finished working on  15558
# Starting to work on  1715531
# Finished working on  1715531
# Starting to work on  495164
# Finished working on  495164
# Starting to work on  2631754
# Finished working on  2631754
# Starting to work on  984817
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[1550: 1860]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.6.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.6.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  1100
# Finished working on  1100
# Starting to work on  1988922
# Finished working on  1988922
# Starting to work on  2151389
# Finished working on  2151389
# Starting to work on  55994
# Finished working on  55994
# Starting to work on  301433
# Finished working on  301433
# Starting to work on  895296
# Finished working on  895296
# Starting to work on  1471
# Finished working on  1471
# Starting to work on  52894
# Finished working on  52894
# Starting to work on  2891782
# Finished working on  2891782
# Starting to work on  333508
# Finished working on  333508
# Starting to work on  33685
# Finished working on  33685
# Starting to work on  1961
# Finished working on  1961
# Starting to work on  4666197
# Finished working on  4666197
# Starting to work on  31830
# Finished working on  31830
# Starting to work on  341847
# Finished working on  341847
# Starting to work on  4321
# Finished working on  4321
# Starting to work on  711
# Finished working on  711
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[1860: 2170]: # 0 : 310, 310: 620, 620: 930, 930: 1240, 1240: 1550, 1550: 1860, 1860: 2170, 2170: 2480, 2480: 2790, 2790: 3100, 3100: 3410
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.7.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.1.7.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on
json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  138858
# Finished working on  138858
# Starting to work on  84874
# Finished working on  84874
# Starting to work on  3083355
# Finished working on  3083355
# Starting to work on  552945
# Finished working on  552945
# Starting to work on  3079313
# Finished working on  3079313
# Starting to work on  1934468
# Finished working on  1934468
# Starting to work on  2157261
# Finished working on  2157261
# Starting to work on  1721870
# Finished working on  1721870
# Starting to work on  1967824
# Finished working on  1967824
# Starting to work on  7969833
# Finished working on  7969833
# Starting to work on  2538985
# Finished working on  2538985
# Starting to work on  1054947
# Finished working on  1054947
# Starting to work on  103859
# Finished working on  103859
# Starting to work on  1377266
# Finished working on  1377266
# Starting to work on  169851
# Finished working on  169851
# Starting to work on  366825
# Finished working on  366825
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/player_info_all_pages.csv')
player_info_ids = player_info['Team_id']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids[6510: 6820]: # 3410: 3720, 3720: 4030, 4030: 4340, 4340: 4650, 4650: 4960, 4960: 5270, 5270: 5580, 5580: 5890, 5890: 6200, 6200: 6510, 6820
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.2.11.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/players_hist.2.11.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  1388361
# Finished working on  1388361
# Starting to work on  3775375
# Finished working on  3775375
# Starting to work on  2080976
# Finished working on  2080976
# Starting to work on  102052
# Finished working on  102052
# Starting to work on  6811913
# Finished working on  6811913
# Starting to work on  4007857
# Finished working on  4007857
# Starting to work on  2105261
# Finished working on  2105261
# Starting to work on  5653401
# Finished working on  5653401
# Starting to work on  6800658
# Finished working on  6800658
# Starting to work on  4834034
# Finished working on  4834034
# Starting to work on  4972062
# Finished working on  4972062
# Starting to work on  92077
# Finished working on  92077
# Starting to work on  3179938
# Finished working on  3179938
# Starting to work on  1832868
# Finished working on  1832868
# Starting to work on  81890
# Finished working on  81890
# Starting to work on  350835
# Finished working on  350835
# ...

# %%
import requests
import json
import pandas as pd

base_url = 'https://fantasy.premierleague.com/api/'

player_info = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/extra_player_info.csv')
player_info_ids = player_info['manager']


# For each manager, get their pick history
manager_picks = []
for id_ in player_info_ids: # 3410: 3720, 3720: 4030, 4030: 4340, 4340: 4650, 4650: 4960, 4960: 5270, 5270: 5580, 5580: 5890, 5890: 6200, 6200: 6510, 6820
    print('Starting to work on ', id_)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(base_url + "entry/" + str(id_) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",gw, '=========> ', id_)
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)
    manager_picks.append({id_: picks})

    # Append the manager league details to a json file
    data_file_contents = []
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/extra_players_hist.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("/content/drive/MyDrive/Colab Notebooks/ids_details/extra_players_hist.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append({id_: picks})
        json.dump(data_file_contents, f)

    print('Finished working on ', id_)
# Out:
# Starting to work on  1489651
# Finished working on  1489651
# Starting to work on  593464
# Finished working on  593464
# Starting to work on  3086421
# Finished working on  3086421
# Starting to work on  429924
# Finished working on  429924
