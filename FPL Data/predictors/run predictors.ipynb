# %%
# %run "./xP_predictor - gk.ipynb"
# Out:
#   dropping 'total_points_per_90_rolling_3' (|corr| with xP=0.899) -- |corr|=0.899 with already-selected 'xP'
#   dropping 'points_rolling_3' (|corr| with xP=0.897) -- |corr|=0.897 with already-selected 'xP'
#   dropping 'points_3_ewm' (|corr| with xP=0.897) -- |corr|=0.897 with already-selected 'xP'
#   dropping 'points_5_ewm' (|corr| with xP=0.895) -- |corr|=0.895 with already-selected 'xP'
#   dropping 'total_points_per_90_5_ewm' (|corr| with xP=0.894) -- |corr|=0.894 with already-selected 'xP'
#   dropping 'total_points_per_90_3_ewm' (|corr| with xP=0.891) -- |corr|=0.891 with already-selected 'xP'
#   dropping 'xP_rolling_1' (|corr| with xP=0.849) -- |corr|=0.849 with already-selected 'xP'
#   dropping 'xP_1_ewm' (|corr| with xP=0.849) -- |corr|=0.849 with already-selected 'xP'
#   dropping 'xP_3_ewm' (|corr| with xP=0.823) -- |corr|=0.823 with already-selected 'xP'
#   dropping 'minutes_rolling_3' (|corr| with xP=0.810) -- |corr|=0.810 with already-selected 'xP'
# ...

# %%
# %run "./xP_predictor - def.ipynb"
# Out:
#   dropping 'points_rolling_3' (|corr| with xP=0.884) -- |corr|=0.884 with already-selected 'xP'
#   dropping 'points_3_ewm' (|corr| with xP=0.868) -- |corr|=0.868 with already-selected 'xP'
#   dropping 'points_5_ewm' (|corr| with xP=0.866) -- |corr|=0.866 with already-selected 'xP'
#   dropping 'xP_1_ewm' (|corr| with xP=0.864) -- |corr|=0.864 with already-selected 'xP'
#   dropping 'xP_rolling_1' (|corr| with xP=0.864) -- |corr|=0.864 with already-selected 'xP'
#   dropping 'xP_3_ewm' (|corr| with xP=0.845) -- |corr|=0.845 with already-selected 'xP'
#   dropping 'xP_rolling_3' (|corr| with xP=0.816) -- |corr|=0.816 with already-selected 'xP'
#   dropping 'xP_5_ewm' (|corr| with xP=0.811) -- |corr|=0.811 with already-selected 'xP'
#   dropping 'clean_sheets_rolling_3' (|corr| with xP=0.774) -- |corr|=0.774 with already-selected 'xP'
#   dropping 'clean_sheets_per_90_rolling_3' (|corr| with xP=0.762) -- |corr|=0.762 with already-selected 'xP'
# ...

# %%
# %run "./xP_predictor - mid.ipynb"
# Out:
#   dropping 'points_rolling_3' (|corr| with xP=0.918) -- |corr|=0.918 with already-selected 'xP'
#   dropping 'points_3_ewm' (|corr| with xP=0.892) -- |corr|=0.892 with already-selected 'xP'
#   dropping 'points_5_ewm' (|corr| with xP=0.888) -- |corr|=0.888 with already-selected 'xP'
#   dropping 'xP_3_ewm' (|corr| with xP=0.887) -- |corr|=0.887 with already-selected 'xP'
#   dropping 'xP_1_ewm' (|corr| with xP=0.887) -- |corr|=0.887 with already-selected 'xP'
#   dropping 'xP_rolling_1' (|corr| with xP=0.887) -- |corr|=0.887 with already-selected 'xP'
#   dropping 'influence_rolling_3' (|corr| with xP=0.883) -- |corr|=0.883 with already-selected 'xP'
#   dropping 'xP_rolling_3' (|corr| with xP=0.866) -- |corr|=0.866 with already-selected 'xP'
#   dropping 'xP_5_ewm' (|corr| with xP=0.864) -- |corr|=0.864 with already-selected 'xP'
#   dropping 'influence_3_ewm' (|corr| with xP=0.849) -- |corr|=0.849 with already-selected 'xP'
# ...

# %%
# %run "./xP_predictor - fwd.ipynb"
# Out:
#   dropping 'points_rolling_3' (|corr| with xP=0.933) -- |corr|=0.933 with already-selected 'xP'
#   dropping 'points_3_ewm' (|corr| with xP=0.909) -- |corr|=0.909 with already-selected 'xP'
#   dropping 'points_5_ewm' (|corr| with xP=0.903) -- |corr|=0.903 with already-selected 'xP'
#   dropping 'influence_rolling_3' (|corr| with xP=0.899) -- |corr|=0.899 with already-selected 'xP'
#   dropping 'xP_1_ewm' (|corr| with xP=0.894) -- |corr|=0.894 with already-selected 'xP'
#   dropping 'xP_rolling_1' (|corr| with xP=0.894) -- |corr|=0.894 with already-selected 'xP'
#   dropping 'xP_3_ewm' (|corr| with xP=0.892) -- |corr|=0.892 with already-selected 'xP'
#   dropping 'ict_index_rolling_3' (|corr| with xP=0.890) -- |corr|=0.890 with already-selected 'xP'
#   dropping 'xP_5_ewm' (|corr| with xP=0.881) -- |corr|=0.881 with already-selected 'xP'
#   dropping 'influence_3_ewm' (|corr| with xP=0.877) -- |corr|=0.877 with already-selected 'xP'
# ...
