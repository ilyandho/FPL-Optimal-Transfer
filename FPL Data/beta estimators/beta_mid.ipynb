# %%
import pandas as pd
import joblib

from utils import fit_position_pipeline, select_features_by_correlation

# %%
features = joblib.load('../predictors/hist/feats_mid')
player_data = pd.read_csv('../rolled_data_24_25.csv')
player_data = player_data[player_data['position'] == 'Midfielder']

league_models = {}

for gw in range(6,39):
    print(f"\n{'=' * 60}\n Model for round {gw} \n{'=' * 60}")
    data = player_data[(player_data['round']>3) & (player_data['round'] < gw)].fillna(0)
    feats = features[gw]
    feats.remove('xP')
    selected_feats = select_features_by_correlation(data, feats, target_col='xP', redundancy_threshold=0.45, min_corr=0.15, verbose=True)


    league_model = fit_position_pipeline(
            data, selected_feats, gw, position_name='MID', random_seed=42
        )

    print(f"Features for MID kept in gw {gw} -> {league_model['feats']}")

    league_models[gw] = league_model
# Out:
# ============================================================
#  Model for round 6
# ============================================================
#
# Selected 18 / 18 features (ranked by |corr| with 'xP', redundancy_threshold=0.5, min_corr=0.1):
# ['opponent_difficulty', 'elo_diff', 'goals_scored_rolling_1', 'yellow_cards_rolling_3', 'expected_assists_rolling_1', 'blocks_rolling_3', 'tackles_won_percent_rolling_1', 'clean_sheets_per_90_rolling_1', 'assists_1_ewm', 'expected_goals_conceded_1_ewm', 'interceptions_1_ewm', 'clearances_5_ewm', 'team_xG_5_ewm', 'expected_goals_per_90_3_ewm', 'expected_goals_conceded_per_90_3_ewm', 'chances_created_per_90_1_ewm', 'chances_created_per_90_5_ewm', 'recoveries_per_90_5_ewm']
#
# ============================================================
# Position: MID
# ============================================================
# n_players=605, n_features=18
# X shape: (605, 18)
# rank: 18  (full rank would be 18)
# condition number: 3.39e+00
#   (as a rough guide: >1e3 is concerning, >1e6 is basically singular)
# Fitting initial model...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 52 seconds.
#   divergences: 0
#   dropping 'goals_scored_rolling_1' (label beta[2]) -- HDI near-duplicate of 'expected_goals_conceded_1_ewm' (label beta[9])
#   dropping 'assists_1_ewm' (label beta[8]) -- HDI near-duplicate of 'opponent_difficulty' (label beta[0])
#   dropping 'clearances_5_ewm' (label beta[11]) -- HDI near-duplicate of 'chances_created_per_90_1_ewm' (label beta[15])
#   dropping 'interceptions_1_ewm' (label beta[10]) -- HDI near-duplicate of 'chances_created_per_90_1_ewm' (label beta[15])
# Kept 5 / 18 features: ['opponent_difficulty', 'expected_assists_rolling_1', 'clean_sheets_per_90_rolling_1', 'expected_goals_conceded_1_ewm', 'chances_created_per_90_1_ewm']
# Refitting on pruned feature set...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 35 seconds.
#   divergences: 0
# Features for MID kept in gw 6 -> ['opponent_difficulty', 'expected_assists_rolling_1', 'clean_sheets_per_90_rolling_1', 'expected_goals_conceded_1_ewm', 'chances_created_per_90_1_ewm']
#
# ============================================================
#  Model for round 7
# ============================================================
#
# Selected 23 / 23 features (ranked by |corr| with 'xP', redundancy_threshold=0.5, min_corr=0.1):
# ['transfers_balance', 'transfers_out', 'elo_diff', 'influence_rolling_5', 'blocks_rolling_3', 'blocks_rolling_5', 'total_points_per_90_rolling_1', 'assists_per_90_rolling_1', 'clean_sheets_per_90_rolling_1', 'expected_goals_conceded_per_90_rolling_3', 'chances_created_per_90_rolling_5', 'goals_scored_1_ewm', 'goals_conceded_1_ewm', 'yellow_cards_3_ewm', 'expected_assists_1_ewm', 'clearances_5_ewm', 'tackles_won_percent_1_ewm', 'team_xG_5_ewm', 'assists_per_90_3_ewm', 'expected_goals_per_90_3_ewm', 'chances_created_per_90_5_ewm', 'recoveries_1_ewm', 'recoveries_per_90_5_ewm']
#
# ============================================================
# Position: MID
# ============================================================
# n_players=908, n_features=23
# X shape: (908, 23)
# rank: 23  (full rank would be 23)
# condition number: 4.09e+00
#   (as a rough guide: >1e3 is concerning, >1e6 is basically singular)
# Fitting initial model...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta]
# Output()

# %%
joblib.dump(league_models, './estimates/league_models_mid')
