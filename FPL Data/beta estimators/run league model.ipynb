# %%
# %run './beta_gk.ipynb'
# Out:
# ...
#  Model for round 6
# ...
#   dropping 'points_5_ewm' (|corr| with xP=0.895) -- |corr|=0.974 with already-selected 'points_3_ewm'
#   dropping 'minutes_rolling_3' (|corr| with xP=0.810) -- |corr|=0.864 with already-selected 'points_3_ewm'
#   dropping 'starts_rolling_3' (|corr| with xP=0.809) -- |corr|=0.861 with already-selected 'points_3_ewm'
#   dropping 'xP_5_ewm' (|corr| with xP=0.794) -- |corr|=0.821 with already-selected 'points_3_ewm'
#   dropping 'ict_index_3_ewm' (|corr| with xP=0.759) -- |corr|=0.867 with already-selected 'points_3_ewm'
#   dropping 'clean_sheets_3_ewm' (|corr| with xP=0.757) -- |corr|=0.825 with already-selected 'points_3_ewm'
#   dropping 'ict_index_rolling_3' (|corr| with xP=0.739) -- |corr|=0.832 with already-selected 'points_3_ewm'
#   dropping 'saves_3_ewm' (|corr| with xP=0.714) -- |corr|=0.821 with already-selected 'points_3_ewm'
#   dropping 'saves_rolling_5' (|corr| with xP=0.690) -- |corr|=0.778 with already-selected 'points_3_ewm'
# ...

# %%
# %run './beta_def.ipynb'
# Out:
# /home/ilyandho/micromamba/envs/pycaret/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/ilyandho/micromamba/envs/pycaret/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Initializing NUTS using jitter+adapt_diag...
# ...
#  Model for round 6
# ...
#   dropping 'xP_3_ewm' (|corr| with xP=0.845) -- |corr|=0.868 with already-selected 'points_3_ewm'
#   dropping 'clean_sheets_3_ewm' (|corr| with xP=0.731) -- |corr|=0.821 with already-selected 'points_3_ewm'
#   dropping 'ict_index_3_ewm' (|corr| with xP=0.701) -- |corr|=0.785 with already-selected 'points_3_ewm'
#   dropping 'minutes_rolling_3' (|corr| with xP=0.684) -- |corr|=0.765 with already-selected 'points_3_ewm'
#   dropping 'starts_rolling_3' (|corr| with xP=0.676) -- |corr|=0.757 with already-selected 'points_3_ewm'
# ...

# %%
# %run './beta_mid.ipynb'
# Out:
# ...
#  Model for round 6
# ...
#   dropping 'xP_3_ewm' (|corr| with xP=0.887) -- |corr|=0.888 with already-selected 'points_3_ewm'
#   dropping 'ict_index_3_ewm' (|corr| with xP=0.829) -- |corr|=0.899 with already-selected 'points_3_ewm'
#   dropping 'expected_goal_involvements_3_ewm' (|corr| with xP=0.786) -- |corr|=0.838 with already-selected 'points_3_ewm'
#   dropping 'expected_goals_3_ewm' (|corr| with xP=0.721) -- |corr|=0.767 with already-selected 'points_3_ewm'
#   dropping 'minutes_rolling_3' (|corr| with xP=0.703) -- |corr|=0.775 with already-selected 'points_3_ewm'
#   dropping 'goals_scored_3_ewm' (|corr| with xP=0.685) -- |corr|=0.751 with already-selected 'points_3_ewm'
#   dropping 'starts_rolling_3' (|corr| with xP=0.667) -- |corr|=0.736 with already-selected 'points_3_ewm'
#   dropping 'expected_assists_3_ewm' (|corr| with xP=0.640) -- |corr|=0.685 with already-selected 'points_3_ewm'
# ...

# %%
# %run './beta_fwd.ipynb'
# Out:
# Initializing NUTS using jitter+adapt_diag...
# ...
#  Model for round 6
# ...
#   dropping 'xP_3_ewm' (|corr| with xP=0.892) -- |corr|=0.937 with already-selected 'points_3_ewm'
#   dropping 'ict_index_3_ewm' (|corr| with xP=0.876) -- |corr|=0.954 with already-selected 'points_3_ewm'
#   dropping 'goals_scored_3_ewm' (|corr| with xP=0.826) -- |corr|=0.928 with already-selected 'points_3_ewm'
#   dropping 'expected_goal_involvements_3_ewm' (|corr| with xP=0.825) -- |corr|=0.901 with already-selected 'points_3_ewm'
#   dropping 'expected_goals_3_ewm' (|corr| with xP=0.816) -- |corr|=0.887 with already-selected 'points_3_ewm'
#   dropping 'minutes_rolling_3' (|corr| with xP=0.778) -- |corr|=0.823 with already-selected 'points_3_ewm'
#   dropping 'starts_rolling_3' (|corr| with xP=0.731) -- |corr|=0.779 with already-selected 'points_3_ewm'
#   dropping 'expected_assists_3_ewm' (|corr| with xP=0.476) -- |corr|=0.548 with already-selected 'points_3_ewm'
# ...
