# %%
# %run './beta_gk.ipynb'
# Out:
# Initializing NUTS using jitter+adapt_diag...
# ...
#  Model for round 6
# ...
#   dropping 'transfers_in' (|corr| with xP=0.594) -- |corr|=0.508 with already-selected 'expected_goals_conceded_1_ewm'
#   dropping 'sweeper_actions_per_90_rolling_3' (|corr| with xP=0.585) -- |corr|=0.564 with already-selected 'expected_goals_conceded_1_ewm'
#   dropping 'yellow_cards_rolling_3' (|corr| with xP=0.473) -- |corr|=0.549 with already-selected 'clean_sheets_1_ewm'
#   dropping 'expected_goal_involvements_rolling_1' (|corr| with xP=0.280) -- |corr|=0.567 with already-selected 'interceptions_per_90_rolling_3'
#   dropping 'expected_goal_involvements_rolling_3' (|corr| with xP=0.222) -- |corr|=0.507 with already-selected 'interceptions_per_90_rolling_3'
#   dropping 'opponent_difficulty' (|corr| with xP=0.208) -- |corr|=0.510 with already-selected 'elo_diff'
#   skipping 'was_home' -- |corr| with xP (0.137) below min_corr=0.15
#   skipping 'tackles_1_ewm' -- |corr| with xP (0.106) below min_corr=0.15
# ...

# %%
# %run './beta_def.ipynb'
# Out:
# Initializing NUTS using jitter+adapt_diag...
# ...
#  Model for round 6
# ...
#   dropping 'tackles_won_percent_rolling_1' (|corr| with xP=0.440) -- |corr|=0.463 with already-selected 'expected_goals_conceded_rolling_3'
#   dropping 'expected_goals_5_ewm' (|corr| with xP=0.429) -- |corr|=0.452 with already-selected 'expected_goals_conceded_rolling_3'
#   dropping 'transfers_out' (|corr| with xP=0.410) -- |corr|=0.409 with already-selected 'expected_assists_rolling_3'
#   dropping 'interceptions_1_ewm' (|corr| with xP=0.402) -- |corr|=0.427 with already-selected 'expected_goals_conceded_rolling_3'
#   dropping 'clearances_per_90_5_ewm' (|corr| with xP=0.376) -- |corr|=0.479 with already-selected 'expected_goals_conceded_rolling_3'
#   dropping 'blocks_per_90_rolling_3' (|corr| with xP=0.342) -- |corr|=0.456 with already-selected 'expected_goals_conceded_rolling_3'
#   dropping 'opponent_difficulty' (|corr| with xP=0.246) -- |corr|=0.458 with already-selected 'elo_diff'
# ...

# %%
# %run './beta_mid.ipynb'
# Out:
# Initializing NUTS using jitter+adapt_diag...
# ...
#  Model for round 6
# ...
#   dropping 'clearances_5_ewm' (|corr| with xP=0.369) -- |corr|=0.478 with already-selected 'expected_goals_conceded_1_ewm'
#   dropping 'tackles_won_percent_rolling_1' (|corr| with xP=0.368) -- |corr|=0.497 with already-selected 'expected_goals_conceded_1_ewm'
#   dropping 'assists_1_ewm' (|corr| with xP=0.344) -- |corr|=0.480 with already-selected 'expected_assists_rolling_1'
#   dropping 'interceptions_1_ewm' (|corr| with xP=0.273) -- |corr|=0.467 with already-selected 'expected_goals_conceded_1_ewm'
#   dropping 'chances_created_per_90_1_ewm' (|corr| with xP=0.195) -- |corr|=0.453 with already-selected 'chances_created_per_90_5_ewm'
#
# Selected 13 / 18 features (ranked by |corr| with 'xP', redundancy_threshold=0.45, min_corr=0.15):
# ...

# %%
# %run './beta_fwd.ipynb'
# Out:
# Initializing NUTS using jitter+adapt_diag...
# ...
#  Model for round 6
# ...
#   dropping 'interceptions_rolling_3' (|corr| with xP=0.427) -- |corr|=0.490 with already-selected 'assists_5_ewm'
#   dropping 'tackles_won_percent_rolling_1' (|corr| with xP=0.352) -- |corr|=0.478 with already-selected 'clearances_3_ewm'
#   dropping 'opponent_xG_1_ewm' (|corr| with xP=0.185) -- |corr|=0.474 with already-selected 'opponent_difficulty'
#   dropping 'big_chances_faced_5_ewm' (|corr| with xP=0.177) -- |corr|=0.455 with already-selected 'opponent_difficulty'
#
# Selected 13 / 17 features (ranked by |corr| with 'xP', redundancy_threshold=0.45, min_corr=0.15):
# ['opponent_difficulty', 'elo_diff', 'ownership_change', 'creativity_rolling_1', 'blocks_rolling_1', 'blocks_per_90_rolling_3', 'tackles_won_percent_per_90_rolling_3', 'assists_5_ewm', 'yellow_cards_5_ewm', 'clearances_3_ewm', 'goals_scored_per_90_1_ewm', 'assists_per_90_1_ewm', 'expected_goal_involvements_per_90_3_ewm']
#
# ...
# Position: FWD
# ...
