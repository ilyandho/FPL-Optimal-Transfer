# %%
import pandas as pd
import numpy as np
import os

# %%
# %run "./data/odds/get_next_odds.ipynb"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_29408\1150422882.py:3
#       1 premLeague = "https://sports.williamhill.com/betting/en-gb/football/competitions/OB_TY295/English-Premier-League/matches/OB_MGMB/Match-Betting"
# ----> 3 driver = webdriver.Firefox()
#       4 driver.get(premLeague)
#       5 matches = driver.find_elements(By.CSS_SELECTOR, "article.sp-o-market--default")[0:10]
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\firefox\webdriver.py:57, in WebDriver.__init__(self, options, service, keep_alive)
#      54 options = options if options else Options()
#      56 finder = DriverFinder(self.service, options)
# ---> 57 if finder.get_browser_path():
#      58     options.binary_location = finder.get_browser_path()
#      59     options.browser_version = None
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:67, in DriverFinder._binary_paths(self)
#      65     self._paths["driver_path"] = path
#      66 else:
# ---> 67     output = SeleniumManager().binary_paths(self._to_args())
#      68     if Path(output["driver_path"]).is_file():
#      69         self._paths["driver_path"] = output["driver_path"]
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:55, in SeleniumManager.binary_paths(self, args)
#      52 args.append("--output")
#      53 args.append("json")
# ---> 55 return self._run(args)
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:117, in SeleniumManager._run(args)
#     115 try:
#     116     if sys.platform == "win32":
# --> 117         completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     118     else:
#     119         completed_proc = subprocess.run(args, capture_output=True)
#
# File c:\Users\Ilyas\anaconda3\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File c:\Users\Ilyas\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\Ilyas\anaconda3\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_ipython().run_line_magic('run', '"./data/odds/get_next_odds.ipynb"')
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_29408\1150422882.py:3
#       1 premLeague = "https://sports.williamhill.com/betting/en-gb/football/competitions/OB_TY295/English-Premier-League/matches/OB_MGMB/Match-Betting"
# ----> 3 driver = webdriver.Firefox()
#       4 driver.get(premLeague)
#       5 matches = driver.find_elements(By.CSS_SELECTOR, "article.sp-o-market--default")[0:10]
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\firefox\webdriver.py:57, in WebDriver.__init__(self, options, service, keep_alive)
#      54 options = options if options else Options()
#      56 finder = DriverFinder(self.service, options)
# ---> 57 if finder.get_browser_path():
#      58     options.binary_location = finder.get_browser_path()
#      59     options.browser_version = None
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:67, in DriverFinder._binary_paths(self)
#      65     self._paths["driver_path"] = path
#      66 else:
# ---> 67     output = SeleniumManager().binary_paths(self._to_args())
#      68     if Path(output["driver_path"]).is_file():
#      69         self._paths["driver_path"] = output["driver_path"]
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:55, in SeleniumManager.binary_paths(self, args)
#      52 args.append("--output")
#      53 args.append("json")
# ---> 55 return self._run(args)
#
# File c:\Users\Ilyas\anaconda3\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:117, in SeleniumManager._run(args)
#     115 try:
#     116     if sys.platform == "win32":
# --> 117         completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     118     else:
#     119         completed_proc = subprocess.run(args, capture_output=True)
#
# File c:\Users\Ilyas\anaconda3\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File c:\Users\Ilyas\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\Ilyas\anaconda3\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# KeyboardInterrupt:

# %%
players_known = pd.read_csv('./fpl_understat_id_name.csv')
players_known
# Out:
#      fpl_id                             fpl_name  fpl_position         team  \
# 0         4                          Kai Havertz             4      Arsenal
# 1         9             Gabriel Martinelli Silva             3      Arsenal
# 2        17                          Bukayo Saka             3      Arsenal
# 3       633                         Mikel Merino             3      Arsenal
# 4        23                     Leandro Trossard             3      Arsenal
# ..      ...                                  ...           ...          ...
# 536     564                       Santiago Bueno             2       Wolves
# 537     731                        Andrés García             2  Aston Villa
# 538      35            Diego Carlos Santos Silva             2  Aston Villa
# 539     664                           Alfie Pond             2       Wolves
# 540     617  Francisco Evanilson de Lima Barbosa             4  Bournemouth
#
#               full_team_name      understat_name  understat_id
# 0                    Arsenal         Kai Havertz          5220
# 1                    Arsenal  Gabriel Martinelli          7752
# 2                    Arsenal         Bukayo Saka          7322
# 3                    Arsenal        Mikel Merino          5304
# 4                    Arsenal    Leandro Trossard          7698
# ..                       ...                 ...           ...
# 536  Wolverhampton Wanderers      Santiago Bueno         10945
# 537              Aston Villa               André         13022
# 538              Aston Villa        Carlos Forbs         13092
# 539  Wolverhampton Wanderers          Alfie Pond         13117
# 540              Bournemouth          Pedro Lima         13156
#
# [541 rows x 7 columns]

# %%
def save_fpl_players_24_25(fpl_subfolders, season):
    for folder in fpl_subfolders:
        player_id = int(folder.split('/')[-1].split('_')[-1])

        if players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist():
            # print(player_id, players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist(), players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist()[0])
            player_df = pd.read_csv(str(folder+'/gw.csv'))
            player_df['fpl_id'] = players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist()[0]
            player_dir = './data/joint/'+str(season)+'/fpl/'

            # Check if player_dir exists
            if not os.path.exists(player_dir):
                os.makedirs(player_dir)
            player_df.to_csv(player_dir + str(player_id) + '.csv', index_label=False)


    print(' successfully cleaned 20'+ season +' fpl data')

# Understat Files
def save_under_players_24_25(understat_files, season):
    for file_ in understat_files:
        player_id = file_.split('/')[-1].split('_')[-1].split('.csv')[0]
        player_df = pd.read_csv(str(file_))
        player_df['understat_id'] = player_id
        player_dir = './data/joint/'+str(season)+'/understat/'

        # Check if player_dir exists
        if not os.path.exists(player_dir):
            os.makedirs(player_dir)
        player_df.to_csv(player_dir + str(player_id) + '.csv', index_label=False)

    print('successfully cleaned understat 20'+ season +' data')

def joint_players_info_24_25(fpl_player_folder_path, understat_player_folder_path, season):
    fpl_subfolders = [ f.path for f in os.scandir(fpl_player_folder_path) if f.is_dir() ]
    under_files = [ f.path for f in os.scandir(understat_player_folder_path) if f.is_file() ]
    save_fpl_players_24_25(fpl_subfolders, season)
    save_under_players_24_25(under_files, season)

    print('20'+ season +' fpl and understat data now in `joint` folder')

# %%
all_players_details = pd.read_csv('./fpl_understat_id_name.csv') # From ./player_data.ipynbs
player_details_ = all_players_details[all_players_details['fpl_id'] == int(633)]
player_details_['team'].values[0]
# Out:
# 'Arsenal'

# %%
def merge_fpl_understat_data_24_25(fpl_player_folder_path, understat_player_folder_path, season):
    joint_players_info_24_25(fpl_player_folder_path, understat_player_folder_path, season)

    all_players_details = pd.read_csv('./fpl_understat_id_name.csv') # From ./player_data.ipynbs

    joint_fpl_data_path = "./data/joint/"+ season + "/fpl/"
    joint_understat_path = "./data/joint/"+ season + "/understat/"

    understat_files = next(os.walk(joint_understat_path), (None, None, []))[2]  # [] if no file
    fpl_files = next(os.walk(joint_fpl_data_path), (None, None, []))[2]  # [] if no file

    understat_names = [file_.split('.')[0] for file_ in understat_files]
    fpl_file_names = [file_.split('.')[0] for file_ in fpl_files]

    for fpl_id in fpl_file_names:
        player_details_ = all_players_details[all_players_details['fpl_id'] == int(fpl_id)]
        under_id = player_details_['understat_id'].values[0]

        fpl_player = pd.read_csv(joint_fpl_data_path + fpl_id + '.csv')
        understat_player = pd.read_csv(joint_understat_path + str(under_id) + '.csv')

        # Change 'kickoff_time' column name to 'date
        fpl_player_data = fpl_player.rename(columns={'kickoff_time': 'date'})

        # change the formats: From 2021-10-03T13:00:00Z to 2021-10-03
        fpl_player_data.date = fpl_player_data.date.apply(lambda x: x.split('T')[0])

        # Dates are of the form 2021-10-03T13:00:00Z
        fpl_dates_min = fpl_player_data['date'].min()
        fpl_dates_max = fpl_player_data['date'].max()

        # Filter out player info not in the range of dates we are dealing with
        understat_filtered = understat_player[(pd.to_datetime(understat_player['date']) >= pd.to_datetime(fpl_dates_min))
                                                    & (pd.to_datetime(understat_player['date']) <= pd.to_datetime(fpl_dates_max) )]

        # Marge fpl_player_data with understat_player_data if the dates match
        player_data_merged = fpl_player_data.merge(understat_filtered, on="date")

        # Add player team
        def set_player_team(row):
            return row['h_team'] if row['was_home'] else row['a_team']

        with_team = player_data_merged.apply(set_player_team, axis=1)
        player_data_merged['player_team'] = player_data_merged.apply(set_player_team, axis=1)


        if(player_data_merged.shape[0]):
            merged_dir = './data/joint/'+ season +'/merged/'
            if not os.path.exists(merged_dir):
                os.makedirs(merged_dir)

            player_data_merged.to_csv(merged_dir+ fpl_id +'.csv', index_label=False )

# %%
merge_fpl_understat_data_24_25("./data/2024-25/players/", "./data/2024-25/understat/", "24-25")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 merge_fpl_understat_data_24_25("./data/2024-25/players/", "./data/2024-25/understat/", "24-25")
#
# Cell In[8], line 2, in merge_fpl_understat_data_24_25(fpl_player_folder_path, understat_player_folder_path, season)
#       1 def merge_fpl_understat_data_24_25(fpl_player_folder_path, understat_player_folder_path, season):
# ----> 2     joint_players_info_24_25(fpl_player_folder_path, understat_player_folder_path, season)
#       4     all_players_details = pd.read_csv('./fpl_understat_id_name.csv') # From ./player_data.ipynbs
#       6     joint_fpl_data_path = "./data/joint/"+ season + "/fpl/"
#
# Cell In[6], line 37, in joint_players_info_24_25(fpl_player_folder_path, understat_player_folder_path, season)
#      35 fpl_subfolders = [ f.path for f in os.scandir(fpl_player_folder_path) if f.is_dir() ]
#      36 under_files = [ f.path for f in os.scandir(understat_player_folder_path) if f.is_file() ]
# ---> 37 save_fpl_players_24_25(fpl_subfolders, season)
#      38 save_under_players_24_25(under_files, season)
#      40 print('20'+ season +' fpl and understat data now in `joint` folder')
#
# Cell In[6], line 5, in save_fpl_players_24_25(fpl_subfolders, season)
#       2 for folder in fpl_subfolders:
#       3     player_id = int(folder.split('/')[-1].split('_')[-1])
# ----> 5     if players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist():
#       6         # print(player_id, players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist(), players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist()[0])
#       7         player_df = pd.read_csv(str(folder+'/gw.csv'))
#       8         player_df['fpl_id'] = players_known[players_known['fpl_id'] == player_id]['fpl_id'].tolist()[0]
#
# NameError: name 'players_known' is not defined
