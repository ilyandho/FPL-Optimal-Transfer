# %%
# %pip install pycaret

# %%
import pandas as pd
from pycaret.regression import *

# %%
gw=28
data_22_23 = pd.read_csv('./data/joint/22-23/merged_player_data.csv',).dropna()
data_23_24 = pd.read_csv('./data/joint/23-24/merged_player_data.csv').dropna()
data_24_25 = pd.read_csv('./data/joint/24-25/merged_player_data.csv')
data_tar = data_24_25[data_24_25['event']==gw]
data_24_25_ = data_24_25[data_24_25['event'] != gw]

data_24_25_ = data_24_25[data_24_25['event'] != 28]

data = pd.concat([data_22_23, data_23_24, data_24_25_])

# %%
mid_data= data[(g_data['minutes_5'] >= 300) & (data['position'] == 'MID')]
mid_data_tar = data_tar[(g_data_tar['minutes_5'] >= 300) & (data_tar['position'] == '3')]

mid_xg_data = mid_data[g_features]
mid_xg_data_tar = mid_data_tar[g_features]

mid_data.reset_index(drop=True, inplace=True)
mid_xg_data.reset_index(drop=True, inplace=True)

mid_xg_data.drop(columns=['position'], inplace=True)
mid_xg_data_tar.drop(columns=['xG', 'position'], inplace=True)

mid_xg_data

# %%
data_tar[data_tar['minutes_5'] < 200][['percenatge_net_transfers', 'ownership_change']]
# Out:
#       percenatge_net_transfers  ownership_change
# 43                   -0.718310           -4224.0
# 53                   -1.000000             -89.0
# 74                   -0.193548            -271.0
# 97                   -1.000000           -2079.0
# 126                  -0.571678          -13721.0
# ...                        ...               ...
# 8718                  0.245072           14316.0
# 8748                 -0.654102            -552.0
# 8765                 -0.681275            -353.0
# 8805                 -0.189241            -117.0
# 8834                  0.454586          115868.0
#
# [283 rows x 2 columns]

# %%
data_tar[['minutes_5','percenatge_net_transfers', 'ownership_change']]
# Out:
#       minutes_5  percenatge_net_transfers  ownership_change
# 43         72.2                 -0.718310           -4224.0
# 53          0.0                 -1.000000             -89.0
# 74         78.0                 -0.193548            -271.0
# 97         53.2                 -1.000000           -2079.0
# 126        81.6                 -0.571678          -13721.0
# ...         ...                       ...               ...
# 8748       78.2                 -0.654102            -552.0
# 8765       30.2                 -0.681275            -353.0
# 8769        NaN                 -0.718805           -3175.0
# 8805       90.0                 -0.189241            -117.0
# 8834       90.0                  0.454586          115868.0
#
# [341 rows x 3 columns]

# %%
features = [ 'position', 'whh', 'whd', 'wha', 'was_home', 'ownership_change',

            'clean_sheets', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'expected_goals_conceded', 'goals_conceded', 'goals_scored', 'ict_index',
            'influence', 'creativity', 'threat', 'minutes', 'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards', 'yellow_cards', 'saves', 'starts',
            'team_a_score', 'team_h_score', 'total_points', 'goals', 'shots', 'xG', 'xA', 'assists_x', 'assists_y', 'key_passes', 'npg', 'npxG', 'xGChain',  'xGBuildup',  'xP',

            'clean_sheets_1', 'expected_assists_1', 'expected_goal_involvements_1', 'expected_goals_1', 'expected_goals_conceded_1', 'goals_conceded_1', 'goals_scored_1', 'ict_index_1',
            'influence_1', 'creativity_1', 'threat_1', 'minutes_1', 'own_goals_1', 'penalties_missed_1', 'penalties_saved_1', 'red_cards_1', 'yellow_cards_1', 'saves_1', 'starts_1',
            'team_a_score_1', 'team_h_score_1', 'total_points_1', 'goals_1', 'shots_1', 'xG_1', 'xA_1', 'assists_x_1', 'assists_y_1', 'key_passes_1', 'npg_1', 'npxG_1', 'xGChain_1',
            'xGBuildup_1',  'xP_1',

            'clean_sheets_2', 'expected_assists_2', 'expected_goal_involvements_2', 'expected_goals_2', 'expected_goals_conceded_2', 'goals_conceded_2', 'goals_scored_2', 'ict_index_2',
            'influence_2', 'creativity_2', 'threat_2', 'minutes_2', 'own_goals_2', 'penalties_missed_2', 'penalties_saved_2', 'red_cards_2', 'yellow_cards_2', 'saves_2', 'starts_2',
            'team_a_score_2', 'team_h_score_2', 'total_points_2', 'goals_2', 'shots_2', 'xG_2', 'xA_2', 'assists_x_2', 'assists_y_2', 'key_passes_2', 'npg_2', 'npxG_2', 'xGChain_2',
            'xGBuildup_2',  'xP_2',

            'clean_sheets_3', 'expected_assists_3', 'expected_goal_involvements_3', 'expected_goals_3', 'expected_goals_conceded_3', 'goals_conceded_3', 'goals_scored_3', 'ict_index_3',
            'influence_3', 'creativity_3', 'threat_3', 'minutes_3', 'own_goals_3', 'penalties_missed_3', 'penalties_saved_3', 'red_cards_3', 'yellow_cards_3', 'saves_3', 'starts_3',
            'team_a_score_3', 'team_h_score_3', 'total_points_3', 'goals_3', 'shots_3', 'xG_3', 'xA_3', 'assists_x_3', 'assists_y_3', 'key_passes_3', 'npg_3', 'npxG_3', 'xGChain_3',
            'xGBuildup_3',  'xP_3',

            'clean_sheets_4', 'expected_assists_4', 'expected_goal_involvements_4', 'expected_goals_4', 'expected_goals_conceded_4', 'goals_conceded_4', 'goals_scored_4', 'ict_index_4',
            'influence_4', 'creativity_4', 'threat_4', 'minutes_4', 'own_goals_4', 'penalties_missed_4', 'penalties_saved_4', 'red_cards_4', 'yellow_cards_4', 'saves_4', 'starts_4',
            'team_a_score_4', 'team_h_score_4', 'total_points_4', 'goals_4', 'shots_4', 'xG_4', 'xA_4', 'assists_x_4', 'assists_y_4', 'key_passes_4', 'npg_4', 'npxG_4', 'xGChain_4',
            'xGBuildup_4',  'xP_4',

            'clean_sheets_5', 'expected_assists_5', 'expected_goal_involvements_5', 'expected_goals_5', 'expected_goals_conceded_5', 'goals_conceded_5', 'goals_scored_5', 'ict_index_5',
            'influence_5', 'creativity_5', 'threat_5', 'minutes_5', 'own_goals_5', 'penalties_missed_5', 'penalties_saved_5', 'red_cards_5', 'yellow_cards_5', 'saves_5', 'starts_5',
            'team_a_score_5', 'team_h_score_5', 'total_points_5', 'goals_5', 'shots_5', 'xG_5', 'xA_5', 'assists_x_5', 'assists_y_5', 'key_passes_5', 'npg_5', 'npxG_5', 'xGChain_5',
            'xGBuildup_5',  'xP_5'
                        ]

g_features = [ 'position',  'xG', 'whh', 'whd', 'wha', 'was_home', 'team_h_difficulty', 'team_a_difficulty', 'percenatge_net_transfers', 'ict_index', 'influence', 'creativity', 'threat',
              'red_cards', 'yellow_cards', 'starts', 'total_points', 'goals', 'shots',

            'expected_assists_1', 'expected_goal_involvements_1', 'expected_goals_1',  'goals_scored_1', 'ict_index_1', 'influence_1', 'creativity_1', 'threat_1', 'minutes_1',
            'red_cards_1', 'yellow_cards_1', 'starts_1', 'team_a_score_1', 'team_h_score_1', 'total_points_1', 'goals_1', 'shots_1', 'xG_1', 'xA_1', 'assists_x_1', 'assists_y_1',
            'key_passes_1', 'npg_1', 'npxG_1', 'xGChain_1', 'xGBuildup_1',  'xP_1',

            'expected_assists_2', 'expected_goal_involvements_2', 'expected_goals_2',  'goals_scored_2', 'ict_index_2', 'influence_2', 'creativity_2', 'threat_2', 'minutes_2',
            'red_cards_2', 'yellow_cards_2', 'starts_2', 'team_a_score_2', 'team_h_score_2', 'total_points_2', 'goals_2', 'shots_2', 'xG_2', 'xA_2', 'assists_x_2', 'assists_y_2',
            'key_passes_2', 'npg_2', 'npxG_2', 'xGChain_2', 'xGBuildup_2',  'xP_2',

            'expected_assists_3', 'expected_goal_involvements_3', 'expected_goals_3',  'goals_scored_3', 'ict_index_3', 'influence_3', 'creativity_3', 'threat_3', 'minutes_3',
            'red_cards_3', 'yellow_cards_3', 'starts_3', 'team_a_score_3', 'team_h_score_3', 'total_points_3', 'goals_3', 'shots_3', 'xG_3', 'xA_3', 'assists_x_3', 'assists_y_3',
            'key_passes_3', 'npg_3', 'npxG_3', 'xGChain_3', 'xGBuildup_3',  'xP_3',

            'expected_assists_4', 'expected_goal_involvements_4', 'expected_goals_4',  'goals_scored_4', 'ict_index_4', 'influence_4', 'creativity_4', 'threat_4', 'minutes_4',
            'red_cards_4', 'yellow_cards_4', 'starts_4', 'team_a_score_4', 'team_h_score_4', 'total_points_4', 'goals_4', 'shots_4', 'xG_4', 'xA_4', 'assists_x_4', 'assists_y_4',
            'key_passes_4', 'npg_4', 'npxG_4', 'xGChain_4', 'xGBuildup_4',  'xP_4',

            'expected_assists_5', 'expected_goal_involvements_5', 'expected_goals_5',  'goals_scored_5', 'ict_index_5', 'influence_5', 'creativity_5', 'threat_5', 'minutes_5',
            'red_cards_5', 'yellow_cards_5', 'starts_5', 'team_a_score_5', 'team_h_score_5', 'total_points_5', 'goals_5', 'shots_5', 'xG_5', 'xA_5', 'assists_x_5', 'assists_y_5',
            'key_passes_5', 'npg_5', 'npxG_5', 'xGChain_5', 'xGBuildup_5',  'xP_5'
]

# for i in range(1, 6):
#     for feature in features:
#         features.append(f'{feature}_{i}')
len(g_features)
# Out:
# 154

# %% [markdown]
# # Goals

# %% [markdown]
# ## Def

# %%
def_data= data[(g_data['minutes_5'] >= 300) & (data['position'] == 'DEF')]
def_data_tar = data_tar[(g_data_tar['minutes_5'] >= 300) & (data_tar['position'] == '2')]

def_xg_data = def_data[g_features]
def_xg_data_tar = def_data_tar[g_features]

def_data.reset_index(drop=True, inplace=True)
def_xg_data.reset_index(drop=True, inplace=True)

# %%
def_xg_data.drop(columns=['position'], inplace=True)
def_xg_data_tar.drop(columns=['xG', 'position'], inplace=True)

# %%
def_xg_data
# Out:
#            xG    whh    whd    wha  was_home  team_h_difficulty  \
# 0    0.000000  0.354  0.281  0.365      True                3.0
# 1    0.000000  0.595  0.230  0.175     False                3.0
# 2    0.014138  0.316  0.271  0.413      True                3.0
# 3    0.047519  0.308  0.290  0.402     False                3.0
# 4    0.000000  0.174  0.228  0.598      True                4.0
# ..        ...    ...    ...    ...       ...                ...
# 318  0.143915  0.464  0.264  0.272      True                2.0
# 319  0.031046  0.460  0.278  0.262     False                3.0
# 320  0.176578  0.509  0.286  0.205      True                2.0
# 321  0.176578  0.509  0.286  0.205      True                2.0
# 322  0.023201  0.376  0.289  0.335      True                3.0
#
#      team_a_difficulty  ownership_change  ict_index  influence  ...  xG_5  \
# 0                  3.0               NaN        3.8       27.2  ...  0.35
# 1                  3.0               NaN        2.1       18.8  ...  0.35
# 2                  3.0               NaN        2.9       12.8  ...  0.10
# 3                  2.0               NaN        1.1        5.2  ...  0.06
# 4                  3.0               NaN        1.8       16.6  ...  0.11
# ..                 ...               ...        ...        ...  ...   ...
# 318                3.0               NaN        2.8       14.2  ...  0.15
# 319                3.0               NaN        4.6       34.8  ...  0.30
# 320                3.0               NaN        4.2       16.0  ...  0.29
# 321                3.0               NaN        4.2       16.0  ...  0.29
# 322                3.0               NaN        2.1       17.2  ...  0.96
#
#      xA_5  assists_x_5  assists_y_5  key_passes_5  npg_5  npxG_5  xGChain_5  \
# 0    0.41          NaN          0.0           2.0    1.0    0.35       0.51
# 1    0.48          NaN          0.0           3.0    1.0    0.35       0.70
# 2    0.48          NaN          0.0           3.0    1.0    0.10       0.61
# 3    0.79          NaN          0.0           3.0    1.0    0.06       0.76
# 4    0.79          NaN          0.0           3.0    1.0    0.11       1.60
# ..    ...          ...          ...           ...    ...     ...        ...
# 318  0.00          NaN          0.0           0.0    0.0    0.15       1.11
# 319  0.00          NaN          0.0           0.0    0.0    0.30       1.18
# 320  0.00          NaN          0.0           0.0    0.0    0.29       1.19
# 321  0.00          NaN          0.0           0.0    0.0    0.29       1.19
# 322  0.27          NaN          0.0           1.0    0.0    0.96       0.43
#
#      xGBuildup_5  xP_5
# 0           0.47  10.5
# 1           0.66  15.0
# 2           0.58  17.7
# 3           0.38  18.9
# 4           1.23  17.6
# ..           ...   ...
# 318         1.09  14.4
# 319         1.01  14.4
# 320         1.01  15.9
# 321         1.01  15.9
# 322         0.21   NaN
#
# [323 rows x 153 columns]

# %%
def_xg_model = setup(def_xg_data, target = 'xG')
# Out:
# <style type="text/css">
# #T_6acc7_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6acc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6acc7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6acc7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6acc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6acc7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6acc7_row0_col1" class="data row0 col1" >2625</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6acc7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6acc7_row1_col1" class="data row1 col1" >xG</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6acc7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6acc7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6acc7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6acc7_row3_col1" class="data row3 col1" >(323, 153)</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6acc7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6acc7_row4_col1" class="data row4 col1" >(323, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6acc7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6acc7_row5_col1" class="data row5 col1" >(226, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6acc7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6acc7_row6_col1" class="data row6 col1" >(97, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6acc7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6acc7_row7_col1" class="data row7 col1" >151</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6acc7_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_6acc7_row8_col1" class="data row8 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6acc7_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_6acc7_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6acc7_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_6acc7_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6acc7_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_6acc7_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6acc7_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_6acc7_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6acc7_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_6acc7_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6acc7_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_6acc7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6acc7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_6acc7_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6acc7_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_6acc7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6acc7_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_6acc7_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6acc7_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_6acc7_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6acc7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6acc7_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_6acc7_row19_col1" class="data row19 col1" >e5a1</td>
#     </tr>
#   </tbody>
# </table>

# %%
def_xg_best = def_xg_model.compare_models()

# %%
def_xg_best
# Out:
# ElasticNet(random_state=2625)

# %%
def_xg_model.evaluate_model(def_xg_best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
preds = def_xg_model.predict_model(def_xg_best, data=def_xg_data_tar)

preds.rename(columns={'prediction_label': 'xG_pred'}, inplace=True)

def_xg_preds = preds[['xG_pred']]
def_xg_preds

def_data_tar = pd.concat([def_data_tar, def_xg_preds], axis=1)
def_data_tar
# Out:
#       assists_x  bonus  bps  clean_sheets  creativity  element  \
# 1267        NaN    NaN  NaN           NaN         NaN      NaN
# 1325        NaN    NaN  NaN           NaN         NaN      NaN
# 1445        NaN    NaN  NaN           NaN         NaN      NaN
# 1634        NaN    NaN  NaN           NaN         NaN      NaN
# 1662        NaN    NaN  NaN           NaN         NaN      NaN
# 3257        NaN    NaN  NaN           NaN         NaN      NaN
# 3510        NaN    NaN  NaN           NaN         NaN      NaN
# 3642        NaN    NaN  NaN           NaN         NaN      NaN
# 3738        NaN    NaN  NaN           NaN         NaN      NaN
# 4666        NaN    NaN  NaN           NaN         NaN      NaN
# 4744        NaN    NaN  NaN           NaN         NaN      NaN
# 4888        NaN    NaN  NaN           NaN         NaN      NaN
# 4963        NaN    NaN  NaN           NaN         NaN      NaN
# 5339        NaN    NaN  NaN           NaN         NaN      NaN
# 8058        NaN    NaN  NaN           NaN         NaN      NaN
#
#       expected_assists  expected_goal_involvements  expected_goals  \
# 1267               NaN                         NaN             NaN
# 1325               NaN                         NaN             NaN
# 1445               NaN                         NaN             NaN
# 1634               NaN                         NaN             NaN
# 1662               NaN                         NaN             NaN
# 3257               NaN                         NaN             NaN
# 3510               NaN                         NaN             NaN
# 3642               NaN                         NaN             NaN
# 3738               NaN                         NaN             NaN
# 4666               NaN                         NaN             NaN
# 4744               NaN                         NaN             NaN
# 4888               NaN                         NaN             NaN
# 4963               NaN                         NaN             NaN
# 5339               NaN                         NaN             NaN
# 8058               NaN                         NaN             NaN
#
#       expected_goals_conceded  ...  xP_5  ownership_change  \
# 1267                      NaN  ...   NaN               NaN
# 1325                      NaN  ...   NaN               NaN
# 1445                      NaN  ...   NaN               NaN
# 1634                      NaN  ...   NaN               NaN
# 1662                      NaN  ...   NaN               NaN
# 3257                      NaN  ...   NaN               NaN
# 3510                      NaN  ...   NaN               NaN
# 3642                      NaN  ...   NaN               NaN
# 3738                      NaN  ...   NaN               NaN
# 4666                      NaN  ...   NaN               NaN
# 4744                      NaN  ...   NaN               NaN
# 4888                      NaN  ...   NaN               NaN
# 4963                      NaN  ...   NaN               NaN
# 5339                      NaN  ...   NaN               NaN
# 8058                      NaN  ...   NaN               NaN
#
#       percenatge_net_transfers  pts_bps    whh    whd    wha  selected_3  \
# 1267                       NaN      NaN  0.649  0.208  0.144   1291115.0
# 1325                       NaN      NaN  0.649  0.208  0.144     58581.0
# 1445                       NaN      NaN  0.649  0.208  0.144   2942169.0
# 1634                       NaN      NaN  0.649  0.208  0.144    631617.0
# 1662                       NaN      NaN  0.649  0.208  0.144   2916848.0
# 3257                       NaN      NaN  0.863  0.087  0.050  11174972.0
# 3510                       NaN      NaN  0.863  0.087  0.050   2554921.0
# 3642                       NaN      NaN  0.863  0.087  0.050    991145.0
# 3738                       NaN      NaN  0.863  0.087  0.050   7710201.0
# 4666                       NaN      NaN  0.288  0.250  0.463   2258708.0
# 4744                       NaN      NaN  0.288  0.250  0.463   7710104.0
# 4888                       NaN      NaN  0.288  0.250  0.463    573560.0
# 4963                       NaN      NaN  0.288  0.250  0.463    508925.0
# 5339                       NaN      NaN  0.400  0.254  0.346   1241330.0
# 8058                       NaN      NaN  0.649  0.208  0.144    274804.0
#
#       selected_5   xG_pred
# 1267   2151439.0  0.064594
# 1325     84556.0  0.064614
# 1445   4665245.0  0.064605
# 1634   1062147.0  0.064447
# 1662   4358089.0  0.064500
# 3257  18516502.0  0.064469
# 3510   3958152.0  0.064550
# 3642   1975561.0  0.064422
# 3738  12824391.0  0.064602
# 4666   4015348.0  0.064599
# 4744  13749981.0  0.064443
# 4888    991822.0  0.064538
# 4963    880821.0  0.064618
# 5339   2716308.0  0.064641
# 8058    394484.0  0.064608
#
# [15 rows x 249 columns]

# %% [markdown]
# ## Mid

# %%
mid_data= data[(g_data['minutes_5'] >= 300) & (data['position'] == 'MID')]
mid_data_tar = data_tar[(g_data_tar['minutes_5'] >= 300) & (data_tar['position'] == '3')]

mid_xg_data = mid_data[g_features]
mid_xg_data_tar = mid_data_tar[g_features]

mid_data.reset_index(drop=True, inplace=True)
mid_xg_data.reset_index(drop=True, inplace=True)

mid_xg_data.drop(columns=['position'], inplace=True)
mid_xg_data_tar.drop(columns=['xG', 'position'], inplace=True)

mid_xg_data

# %%
mid_xg_data.drop(columns=['position'], inplace=True)
mid_xg_data_tar.drop(columns=['xG', 'position'], inplace=True)

mid_xg_data
# Out:
#            xG    whh    whd    wha  was_home  team_h_difficulty  \
# 0    0.057156  0.404  0.275  0.321     False                2.0
# 1    0.000000  0.100  0.189  0.711      True                4.0
# 2    0.000000  0.100  0.189  0.711      True                4.0
# 3    0.729754  0.332  0.266  0.402      True                3.0
# 4    0.172849  0.349  0.282  0.369     False                3.0
# ..        ...    ...    ...    ...       ...                ...
# 306  0.000000  0.464  0.264  0.272      True                2.0
# 307  0.440905  0.460  0.278  0.262     False                3.0
# 308  0.524366  0.509  0.286  0.205      True                2.0
# 309  0.524366  0.509  0.286  0.205      True                2.0
# 310  1.995942  0.376  0.289  0.335      True                3.0
#
#      team_a_difficulty  percenatge_net_transfers  ict_index  influence  ...  \
# 0                  2.0                       NaN        6.7       35.0  ...
# 1                  2.0                       NaN        1.9        7.2  ...
# 2                  2.0                       NaN        1.9        7.2  ...
# 3                  3.0                       NaN        6.6       11.2  ...
# 4                  3.0                       NaN        5.4       12.2  ...
# ..                 ...                       ...        ...        ...  ...
# 306                3.0                       NaN        1.1        5.8  ...
# 307                3.0                       NaN        2.0        6.0  ...
# 308                3.0                       NaN        4.2       10.0  ...
# 309                3.0                       NaN        4.2       10.0  ...
# 310                3.0                       NaN       19.9       74.0  ...
#
#      xG_5  xA_5  assists_x_5  assists_y_5  key_passes_5  npg_5  npxG_5  \
# 0    0.45  0.01          NaN          0.0           1.0    0.0    0.45
# 1    0.63  1.03          NaN          0.0           5.0    0.0    0.63
# 2    0.63  1.03          NaN          0.0           5.0    0.0    0.63
# 3    1.60  0.76          NaN          0.0           8.0    1.0    1.60
# 4    2.33  0.80          NaN          0.0          10.0    1.0    2.33
# ..    ...   ...          ...          ...           ...    ...     ...
# 306  0.62  1.97          NaN          1.0           8.0    0.0    0.62
# 307  0.59  1.97          NaN          1.0           8.0    0.0    0.59
# 308  0.52  1.29          NaN          1.0           4.0    0.0    0.52
# 309  0.52  1.29          NaN          1.0           4.0    0.0    0.52
# 310  0.97  0.03          NaN          0.0           1.0    0.0    0.97
#
#      xGChain_5  xGBuildup_5  xP_5
# 0         0.57         0.12   2.8
# 1         0.97         0.15   8.2
# 2         0.97         0.15   8.2
# 3         2.77         1.21  13.7
# 4         3.50         1.21  17.9
# ..         ...          ...   ...
# 306       3.92         1.76  21.2
# 307       3.79         1.67  18.9
# 308       3.15         1.78  16.4
# 309       3.15         1.78  16.4
# 310       2.48         1.48   NaN
#
# [311 rows x 153 columns]

# %%
mid_xg_model = setup(mid_xg_data, target = 'xG')
# Out:
# <style type="text/css">
# #T_423be_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_423be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_423be_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_423be_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_423be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_423be_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_423be_row0_col1" class="data row0 col1" >4278</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_423be_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_423be_row1_col1" class="data row1 col1" >xG</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_423be_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_423be_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_423be_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_423be_row3_col1" class="data row3 col1" >(311, 153)</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_423be_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_423be_row4_col1" class="data row4 col1" >(311, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_423be_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_423be_row5_col1" class="data row5 col1" >(217, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_423be_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_423be_row6_col1" class="data row6 col1" >(94, 69)</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_423be_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_423be_row7_col1" class="data row7 col1" >151</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_423be_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_423be_row8_col1" class="data row8 col1" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_423be_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_423be_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_423be_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_423be_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_423be_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_423be_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_423be_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_423be_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_423be_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_423be_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_423be_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_423be_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_423be_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_423be_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_423be_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_423be_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_423be_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_423be_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_423be_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_423be_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_423be_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_423be_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_423be_row19_col1" class="data row19 col1" >0720</td>
#     </tr>
#   </tbody>
# </table>

# %%
mid_xg_best = mid_xg_model.compare_models()

# %%
mid_xg_best
# Out:
# ElasticNet(random_state=4278)

# %%
preds = mid_xg_model.predict_model(mid_xg_best, data=mid_xg_data_tar)

preds.rename(columns={'prediction_label': 'xG_pred'}, inplace=True)

mid_xg_preds = preds[['xG_pred']]
mid_xg_preds

mid_data_tar = pd.concat([mid_data_tar, mid_xg_preds], axis=1)
mid_data_tar
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 5
#       1 preds = mid_xg_model.predict_model(mid_xg_best, data=mid_xg_data_tar)
#       3 # preds.rename(columns={'prediction_label': 'xG_pred'}, inplace=True)
# ----> 5 mid_xg_preds = preds[['xG_pred']]
#       6 mid_xg_preds
#       8 mid_data_tar = pd.concat([mid_data_tar, mid_xg_preds], axis=1)
#
# File c:\Users\Ilyas\anaconda3\envs\Pycaret\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Ilyas\anaconda3\envs\Pycaret\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Ilyas\anaconda3\envs\Pycaret\Lib\site-packages\pandas\core\indexes\base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['xG_pred'], dtype='object')] are in the [columns]"

# %%
mid_data_tar['xG_pred']
# Out:
#        xG_pred   xG_pred
# 1293  0.214017  0.177326
# 1371  0.228117  0.196526
# 1500  0.208957  0.181041
# 1557  0.212992  0.178486
# 3451  0.204888  0.179121
# 3540  0.224513  0.190935
# 3571  0.221525  0.229661
# 3601  0.203721  0.190499
# 3671  0.225114  0.212789
# 4638  0.215112  0.185546
# 4715  0.221386  0.192123
# 4818  0.227451  0.205608
# 4992  0.202059  0.179007
# 5800  0.212802  0.182886
# 6695  0.222546  0.195696
# 7003  0.209176  0.194810
# 7260  0.237246  0.206310
