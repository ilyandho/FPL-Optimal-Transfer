# %%
# Leagues : https://fantasy.premierleague.com/leagues/2123833/matches/h
# ~ League 2123833: 2123833,
# #~ League 2123834: 2123834,
# #~ League 2123880: 2123880
# Managers : https://fantasy.premierleague.com/entry/7030715/event/38
# Picks : https://fantasy.premierleague.com/api/entry/537340/event/35/picks/
# Match history: https://fantasy.premierleague.com/api/leagues-h2h-matches/league/2123833/?page=1&event=38
# GW History

# Transfers https://fantasy.premierleague.com/api/entry/3335291/transfers/


# List of leagues
# For each manager, get the gw  details
# For each game wk, get the active chip, subs, history, picks

# %%
{"league_id": [{
    "manager_id": [
        {"1": {
            "active_chip": null,
            "automatic_subs": [],
            "entry_history": {"event": 1, "points": 77, "total_points": 77, "rank": 1221598, "rank_sort": 1274201, "overall_rank": 1221598, "percentile_rank": null, "bank": 5, "value": 1000, "event_transfers": 0, "event_transfers_cost": 0, "points_on_bench": 16},
            "picks": [{"element": 597, "position": 1, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 5, "position": 2, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 398, "position": 3, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 131, "position": 4, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 396, "position": 5, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 143, "position": 6, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 353, "position": 7, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 19, "position": 8, "multiplier": 1, "is_captain": false, "is_vice_captain": true}, {"element": 355, "position": 9, "multiplier": 2, "is_captain": true, "is_vice_captain": false}, {"element": 293, "position": 10, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 135, "position": 11, "multiplier": 1, "is_captain": false, "is_vice_captain": false}, {"element": 263, "position": 12, "multiplier": 0, "is_captain": false, "is_vice_captain": false}, {"element": 342, "position": 13, "multiplier": 0, "is_captain": false, "is_vice_captain": false}, {"element": 599, "position": 14, "multiplier": 0, "is_captain": false, "is_vice_captain": false}, {"element": 51, "position": 15, "multiplier": 0, "is_captain": false, "is_vice_captain": false}]}
         }
    ]
}]
},

# %%
import requests
import json
import pandas as pd
# https://fantasy.premierleague.com/api/leagues-h2h-matches/league/{league-ID}/

base_url = 'https://fantasy.premierleague.com/api/'
# https://fantasy.premierleague.com/entry/6124950/event/38
# general_info = requests.get(base_url + "leagues-classic/2286200/standings/").json()

# Get manager details
general_info = requests.get(
    base_url + "leagues-h2h-matches/league/2123880/").json()
general_info['results']
# , "player_name": ele['entry_1_player_name'], "name": ele['entry_1_name']
manager_ids = {ele['entry_1_entry'] for ele in general_info['results']}

# For every manager get gw history
# for i in range(1,39):
# gw =  requests.get(base_url + "entry/3335291/event/1").json()
# gw = requests.get('https://fantasy.premierleague.com/api/entry/3335291/event/38').json()

# gw
manager_ids
# Out:
# {537340,
#  1686526,
#  2691801,
#  4308112,
#  4842479,
#  5867065,
#  6347867,
#  6762211,
#  6765298,
#  7133906,
#  7480061,
#  8795705,
#  8994109,
#  9379697,
#  9397505,
#  9400205}

# %%
pick = requests.get(
    'https://fantasy.premierleague.com/api/entry/537340/event/35/picks/').json()

pick
# Out:
# {'active_chip': None,
#  'automatic_subs': [{'entry': 537340,
#    'element_in': 506,
#    'element_out': 368,
#    'event': 35}],
#  'entry_history': {'event': 35,
#   'points': 32,
#   'total_points': 1896,
#   'rank': 9816738,
#   'rank_sort': 9819222,
#   'overall_rank': 3297009,
#   'percentile_rank': 95,
#   'bank': 13,
#   'value': 1001,
#   'event_transfers': 0,
#   'event_transfers_cost': 0,
#   'points_on_bench': 6},
#  'picks': [{'element': 113,
#    'position': 1,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 290,
#    'position': 2,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 506,
#    'position': 3,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 20,
#    'position': 4,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 362,
#    'position': 5,
#    'multiplier': 2,
#    'is_captain': True,
#    'is_vice_captain': False},
#   {'element': 308,
#    'position': 6,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 504,
#    'position': 7,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 236,
#    'position': 8,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 293,
#    'position': 9,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': True},
#   {'element': 232,
#    'position': 10,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 343,
#    'position': 11,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 524,
#    'position': 12,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 689,
#    'position': 13,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 131,
#    'position': 14,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 368,
#    'position': 15,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False}]}

# %%
# Get manager details
general_info = requests.get(
    base_url + "leagues-h2h-matches/league/" + str(1075227) + "/").json()

# , "player_name": ele['entry_1_player_name'], "name": ele['entry_1_name']
# manager_ids = {ele['entry_1_entry'] for ele in general_info['results']}


# For each manager id, get the the details
# for id_ in manager_ids:
manager_details_ = [{"manager_id": manager['entry_1_entry'], "player_name": manager['entry_1_player_name'],
                     "name": manager['entry_1_name']} for manager in general_info['results']]
manager_details = list(
    {manager['manager_id']: manager for manager in manager_details_}.values())
print(len(manager_details), manager_details)
# For each manager, get their pick history
manager_picks = []
for manager in manager_details:
    if (manager['manager_id'] == None):
        continue
    print(manager)
    picks = []
    for gw in range(1, 39):
        try:
            gw_picks = requests.get(
                base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(gw) + "/picks/").json()
        except requests.exceptions.JSONDecodeError as jsonerror:
            print("JSONEconding Error: ", jsonerror, ", ",
                  gw, '=========> ', manager['manager_id'])
        except requests.exceptions.HTTPError as errh:
            print("Http Error:", errh)
        except requests.exceptions.ConnectionError as errc:
            print("Error Connecting:", errc)
        except requests.exceptions.Timeout as errt:
            print("Timeout Error:", errt)
        except requests.exceptions.RequestException as err:
            print("OOps: Something Else", err)

        picks.append({gw: gw_picks})
    manager_picks.append({manager['manager_id']: picks})

manager_picks
# Out:
# 10 [{'manager_id': 3532852, 'player_name': 'Charnseuk Iammongkol', 'name': 'Dark Force'}, {'manager_id': 4797829, 'player_name': 'Teerut Prowsri', 'name': 'นักมายากล'}, {'manager_id': 366507, 'player_name': 'Vasu Laochariyakul', 'name': 'Nor 3 neither 4'}, {'manager_id': 4401557, 'player_name': 'Anavith P.', 'name': 'ที่สุดของแจ้'}, {'manager_id': 5638206, 'player_name': 'Fuze Kanin', 'name': 'To-The-Moon FC'}, {'manager_id': 3661873, 'player_name': 'Tat Saptaweporn', 'name': 'หวานเจี๊ยบบบบบ..!!'}, {'manager_id': 904661, 'player_name': 'nipat chooswadichai', 'name': 'NIPAT'}, {'manager_id': None, 'player_name': 'AVERAGE', 'name': 'AVERAGE'}, {'manager_id': 6191142, 'player_name': 'Nutch K', 'name': 'KK.Club'}, {'manager_id': 3663839, 'player_name': 'Nithitat Sawaengsat', 'name': 'Wakanda Forever'}]
# {'manager_id': 3532852, 'player_name': 'Charnseuk Iammongkol', 'name': 'Dark Force'}
# {'manager_id': 4797829, 'player_name': 'Teerut Prowsri', 'name': 'นักมายากล'}
# {'manager_id': 366507, 'player_name': 'Vasu Laochariyakul', 'name': 'Nor 3 neither 4'}
# {'manager_id': 4401557, 'player_name': 'Anavith P.', 'name': 'ที่สุดของแจ้'}
# {'manager_id': 5638206, 'player_name': 'Fuze Kanin', 'name': 'To-The-Moon FC'}
# {'manager_id': 3661873, 'player_name': 'Tat Saptaweporn', 'name': 'หวานเจี๊ยบบบบบ..!!'}
# {'manager_id': 904661, 'player_name': 'nipat chooswadichai', 'name': 'NIPAT'}
# {'manager_id': 6191142, 'player_name': 'Nutch K', 'name': 'KK.Club'}
# {'manager_id': 3663839, 'player_name': 'Nithitat Sawaengsat', 'name': 'Wakanda Forever'}
# [{3532852: [{1: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 275,
#        'element_out': 227,
#        'event': 1}],
#      'entry_history': {'event': 1,
#       'points': 75,
#       'total_points': 75,
#       'rank': 1648468,
#       'rank_sort': 1759622,
#       'overall_rank': 1648468,
#       'percentile_rank': None,
#       'bank': 0,
#       'value': 1000,
#       'event_transfers': 0,
#       'event_transfers_cost': 0,
#       'points_on_bench': 12},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 228,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 12,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 396,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 344,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 119,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 227,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 326,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {2: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 2,
#       'points': 59,
#       'total_points': 130,
#       'rank': 1033769,
#       'rank_sort': 1040332,
#       'overall_rank': 1051810,
#       'percentile_rank': None,
#       'bank': 0,
#       'value': 1001,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 6},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 228,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 12,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 396,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 140,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 135,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 119,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 227,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {3: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 3,
#       'points': 39,
#       'total_points': 165,
#       'rank': 6224865,
#       'rank_sort': 6253427,
#       'overall_rank': 2474439,
#       'percentile_rank': None,
#       'bank': 3,
#       'value': 1003,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 5},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 228,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 12,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 140,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 343,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 119,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 227,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {4: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 4,
#       'points': 84,
#       'total_points': 249,
#       'rank': 1439976,
#       'rank_sort': 1471132,
#       'overall_rank': 1508436,
#       'percentile_rank': None,
#       'bank': 7,
#       'value': 1005,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 1},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 228,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 12,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 140,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 343,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 119,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 275,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {5: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 197,
#        'element_out': 131,
#        'event': 5},
#       {'entry': 3532852, 'element_in': 119, 'element_out': 140, 'event': 5}],
#      'entry_history': {'event': 5,
#       'points': 56,
#       'total_points': 305,
#       'rank': 1024149,
#       'rank_sort': 1046509,
#       'overall_rank': 687560,
#       'percentile_rank': None,
#       'bank': 5,
#       'value': 1005,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 13},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 519,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 12,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 119,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 343,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 140,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {6: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 119,
#        'element_out': 26,
#        'event': 6},
#       {'entry': 3532852, 'element_in': 519, 'element_out': 140, 'event': 6}],
#      'entry_history': {'event': 6,
#       'points': 77,
#       'total_points': 378,
#       'rank': 2701701,
#       'rank_sort': 2721342,
#       'overall_rank': 822685,
#       'percentile_rank': None,
#       'bank': 12,
#       'value': 1007,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 4},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 519,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 108,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 119,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 343,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 26,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 140,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {7: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 197,
#        'element_out': 405,
#        'event': 7}],
#      'entry_history': {'event': 7,
#       'points': 45,
#       'total_points': 423,
#       'rank': 5793824,
#       'rank_sort': 5828705,
#       'overall_rank': 1246693,
#       'percentile_rank': None,
#       'bank': 7,
#       'value': 1011,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 9},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 131,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 108,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 140,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 343,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 119,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 519,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {8: {'active_chip': 'wildcard',
#      'automatic_subs': [],
#      'entry_history': {'event': 8,
#       'points': 44,
#       'total_points': 467,
#       'rank': 4773306,
#       'rank_sort': 4820371,
#       'overall_rank': 1366781,
#       'percentile_rank': None,
#       'bank': 4,
#       'value': 1010,
#       'event_transfers': 0,
#       'event_transfers_cost': 0,
#       'points_on_bench': 6},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 225,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 567,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 602,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {9: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 9,
#       'points': 83,
#       'total_points': 550,
#       'rank': 1873180,
#       'rank_sort': 1899435,
#       'overall_rank': 1075712,
#       'percentile_rank': None,
#       'bank': 0,
#       'value': 1016,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 4},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 516,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 567,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 275,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 225,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 405,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {10: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 10,
#       'points': 64,
#       'total_points': 614,
#       'rank': 6031796,
#       'rank_sort': 6061647,
#       'overall_rank': 1243772,
#       'percentile_rank': None,
#       'bank': 0,
#       'value': 1019,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 9},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 639,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 567,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 7,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 275,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 225,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {11: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 11,
#       'points': 32,
#       'total_points': 646,
#       'rank': 4914720,
#       'rank_sort': 4964043,
#       'overall_rank': 1181460,
#       'percentile_rank': None,
#       'bank': 2,
#       'value': 1024,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 5},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 639,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 557,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 225,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 402,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {12: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 12,
#       'points': 85,
#       'total_points': 727,
#       'rank': 692575,
#       'rank_sort': 704825,
#       'overall_rank': 830604,
#       'percentile_rank': None,
#       'bank': 0,
#       'value': 1027,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 8},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 234,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 557,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 678,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 275,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 225,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {13: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 678,
#        'element_out': 526,
#        'event': 13}],
#      'entry_history': {'event': 13,
#       'points': 45,
#       'total_points': 772,
#       'rank': 5559389,
#       'rank_sort': 5608893,
#       'overall_rank': 925365,
#       'percentile_rank': None,
#       'bank': 1,
#       'value': 1032,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 3},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 234,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 678,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 557,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 225,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 275,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 260,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {14: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 14,
#       'points': 65,
#       'total_points': 833,
#       'rank': 1976659,
#       'rank_sort': 1999403,
#       'overall_rank': 876512,
#       'percentile_rank': None,
#       'bank': 0,
#       'value': 1034,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 12},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 260,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 412,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 678,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 275,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 326,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 234,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {15: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 419,
#        'element_out': 311,
#        'event': 15},
#       {'entry': 3532852, 'element_in': 326, 'element_out': 678, 'event': 15}],
#      'entry_history': {'event': 15,
#       'points': 30,
#       'total_points': 863,
#       'rank': 7564295,
#       'rank_sort': 7610972,
#       'overall_rank': 1052228,
#       'percentile_rank': None,
#       'bank': 2,
#       'value': 1034,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 1},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 234,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 419,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 412,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 326,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 60,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 678,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {16: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 590,
#        'element_out': 678,
#        'event': 16},
#       {'entry': 3532852, 'element_in': 220, 'element_out': 355, 'event': 16}],
#      'entry_history': {'event': 16,
#       'points': 71,
#       'total_points': 930,
#       'rank': 188317,
#       'rank_sort': 192722,
#       'overall_rank': 574871,
#       'percentile_rank': None,
#       'bank': 1,
#       'value': 1033,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': -1},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 387,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 220,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 7,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 412,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 590,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 678,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 419,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {17: {'active_chip': None,
#      'automatic_subs': [{'entry': 3532852,
#        'element_in': 419,
#        'element_out': 83,
#        'event': 17},
#       {'entry': 3532852, 'element_in': 412, 'element_out': 678, 'event': 17}],
#      'entry_history': {'event': 17,
#       'points': 56,
#       'total_points': 982,
#       'rank': 2315909,
#       'rank_sort': 2342270,
#       'overall_rank': 615133,
#       'percentile_rank': None,
#       'bank': 71,
#       'value': 1036,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 0},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 419,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 526,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 6,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 412,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 293,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 590,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 678,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 83,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 387,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {18: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 18,
#       'points': 43,
#       'total_points': 1025,
#       'rank': 3240164,
#       'rank_sort': 3267470,
#       'overall_rank': 660646,
#       'percentile_rank': None,
#       'bank': 81,
#       'value': 1040,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 11},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 311,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 419,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 83,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 5,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 526,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 412,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 293,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 590,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 387,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {19: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 19,
#       'points': 45,
#       'total_points': 1066,
#       'rank': 2683906,
#       'rank_sort': 2702461,
#       'overall_rank': 666958,
#       'percentile_rank': None,
#       'bank': 80,
#       'value': 1041,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 11},
#      'picks': [{'element': 275,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 407,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 298,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 83,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 5,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 526,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 412,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 590,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 60,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 293,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 524,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 419,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 197,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {20: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 20,
#       'points': 101,
#       'total_points': 1167,
#       'rank': 63524,
#       'rank_sort': 68121,
#       'overall_rank': 355553,
#       'percentile_rank': None,
#       'bank': 81,
#       'value': 1042,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 7},
#      'picks': [{'element': 524,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
# ...
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 362,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 415,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 301,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 203,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 757,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {33: {'active_chip': None,
#      'automatic_subs': [{'entry': 3663839,
#        'element_in': 409,
#        'element_out': 301,
#        'event': 33},
#       {'entry': 3663839, 'element_in': 279, 'element_out': 353, 'event': 33}],
#      'entry_history': {'event': 33,
#       'points': 70,
#       'total_points': 1895,
#       'rank': 3116340,
#       'rank_sort': 3139874,
#       'overall_rank': 1017661,
#       'percentile_rank': 30,
#       'bank': 3,
#       'value': 1054,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': -1},
#      'picks': [{'element': 409,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 5,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 203,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 757,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 516,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 19,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 7,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 415,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 301,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 519,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 245,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {34: {'active_chip': 'bboost',
#      'automatic_subs': [{'entry': 3663839,
#        'element_in': 245,
#        'element_out': 203,
#        'event': 34},
#       {'entry': 3663839, 'element_in': 279, 'element_out': 362, 'event': 34}],
#      'entry_history': {'event': 34,
#       'points': 96,
#       'total_points': 1983,
#       'rank': 2388559,
#       'rank_sort': 2393812,
#       'overall_rank': 1053367,
#       'percentile_rank': 25,
#       'bank': 0,
#       'value': 1054,
#       'event_transfers': 3,
#       'event_transfers_cost': 8,
#       'points_on_bench': 0},
#      'picks': [{'element': 385,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 5,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 245,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 313,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 6,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 19,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 8,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 415,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 409,
#        'position': 12,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 13,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 203,
#        'position': 14,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 519,
#        'position': 15,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {35: {'active_chip': None,
#      'automatic_subs': [{'entry': 3663839,
#        'element_in': 279,
#        'element_out': 353,
#        'event': 35}],
#      'entry_history': {'event': 35,
#       'points': 74,
#       'total_points': 2053,
#       'rank': 982580,
#       'rank_sort': 996545,
#       'overall_rank': 967427,
#       'percentile_rank': 10,
#       'bank': 4,
#       'value': 1055,
#       'event_transfers': 2,
#       'event_transfers_cost': 4,
#       'points_on_bench': 9},
#      'picks': [{'element': 409,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 5,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 495,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 639,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 6,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 19,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 8,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 415,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 385,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 245,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 313,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {36: {'active_chip': None,
#      'automatic_subs': [],
#      'entry_history': {'event': 36,
#       'points': 91,
#       'total_points': 2144,
#       'rank': 1611532,
#       'rank_sort': 1623896,
#       'overall_rank': 872585,
#       'percentile_rank': 15,
#       'bank': 16,
#       'value': 1057,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 7},
#      'picks': [{'element': 409,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 369,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 5,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 245,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 6,
#        'position': 7,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 19,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 415,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 385,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 639,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 495,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {37: {'active_chip': '3xc',
#      'automatic_subs': [],
#      'entry_history': {'event': 37,
#       'points': 119,
#       'total_points': 2263,
#       'rank': 1174124,
#       'rank_sort': 1181867,
#       'overall_rank': 794005,
#       'percentile_rank': 15,
#       'bank': 5,
#       'value': 1058,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 12},
#      'picks': [{'element': 409,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 369,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 639,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 245,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 373,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 19,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 3,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 415,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 385,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 5,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 495,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}},
#    {38: {'active_chip': None,
#      'automatic_subs': [{'entry': 3663839,
#        'element_in': 385,
#        'element_out': 409,
#        'event': 38},
#       {'entry': 3663839, 'element_in': 245, 'element_out': 19, 'event': 38}],
#      'entry_history': {'event': 38,
#       'points': 67,
#       'total_points': 2330,
#       'rank': 2442812,
#       'rank_sort': 2468990,
#       'overall_rank': 787225,
#       'percentile_rank': 25,
#       'bank': 14,
#       'value': 1058,
#       'event_transfers': 1,
#       'event_transfers_cost': 0,
#       'points_on_bench': 1},
#      'picks': [{'element': 385,
#        'position': 1,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 5,
#        'position': 2,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 639,
#        'position': 3,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 369,
#        'position': 4,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 245,
#        'position': 5,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 6,
#        'position': 6,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 353,
#        'position': 7,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 308,
#        'position': 8,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 362,
#        'position': 9,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': True},
#       {'element': 355,
#        'position': 10,
#        'multiplier': 2,
#        'is_captain': True,
#        'is_vice_captain': False},
#       {'element': 415,
#        'position': 11,
#        'multiplier': 1,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 409,
#        'position': 12,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 19,
#        'position': 13,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 279,
#        'position': 14,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False},
#       {'element': 495,
#        'position': 15,
#        'multiplier': 0,
#        'is_captain': False,
#        'is_vice_captain': False}]}}]}]

# %%
manager_details
# Out:
# [{'manager_id': 3532852,
#   'player_name': 'Charnseuk Iammongkol',
#   'name': 'Dark Force'},
#  {'manager_id': 4797829, 'player_name': 'Teerut Prowsri', 'name': 'นักมายากล'},
#  {'manager_id': 366507,
#   'player_name': 'Vasu Laochariyakul',
#   'name': 'Nor 3 neither 4'},
#  {'manager_id': 4401557, 'player_name': 'Anavith P.', 'name': 'ที่สุดของแจ้'},
#  {'manager_id': 5638206,
#   'player_name': 'Fuze Kanin',
#   'name': 'To-The-Moon FC'},
#  {'manager_id': 3661873,
#   'player_name': 'Tat Saptaweporn',
#   'name': 'หวานเจี๊ยบบบบบ..!!'},
#  {'manager_id': 904661, 'player_name': 'nipat chooswadichai', 'name': 'NIPAT'},
#  {'manager_id': None, 'player_name': 'AVERAGE', 'name': 'AVERAGE'},
#  {'manager_id': 6191142, 'player_name': 'Nutch K', 'name': 'KK.Club'},
#  {'manager_id': 3663839,
#   'player_name': 'Nithitat Sawaengsat',
#   'name': 'Wakanda Forever'}]

# %%
# For each manager, get their pick history
manager_picks = []
# for manager in manager_details:
#     picks = []
manager = {'manager_id': 3532852,
           'player_name': 'Charnseuk Iammongkol', 'name': 'Dark Force'}
# for gw in range(1, 39):
gw_picks = requests.get(
    base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(1) + "/picks/").json()

gw_picks
# Out:
# {'active_chip': None,
#  'automatic_subs': [{'entry': 3532852,
#    'element_in': 275,
#    'element_out': 227,
#    'event': 1}],
#  'entry_history': {'event': 1,
#   'points': 75,
#   'total_points': 75,
#   'rank': 1648468,
#   'rank_sort': 1759622,
#   'overall_rank': 1648468,
#   'percentile_rank': None,
#   'bank': 0,
#   'value': 1000,
#   'event_transfers': 0,
#   'event_transfers_cost': 0,
#   'points_on_bench': 12},
#  'picks': [{'element': 275,
#    'position': 1,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 405,
#    'position': 2,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 131,
#    'position': 3,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 228,
#    'position': 4,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 12,
#    'position': 5,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 308,
#    'position': 6,
#    'multiplier': 2,
#    'is_captain': True,
#    'is_vice_captain': False},
#   {'element': 396,
#    'position': 7,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 402,
#    'position': 8,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 344,
#    'position': 9,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 355,
#    'position': 10,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': True},
#   {'element': 119,
#    'position': 11,
#    'multiplier': 1,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 227,
#    'position': 12,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 326,
#    'position': 13,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 197,
#    'position': 14,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 407,
#    'position': 15,
#    'multiplier': 0,
#    'is_captain': False,
#    'is_vice_captain': False}]}

# %%
v = [
    {'active_chip': None,
     'automatic_subs': [{'entry': 3532852,
                         'element_in': 275,
                         'element_out': 227,
                         'event': 1}],
     'entry_history': {'event': 1,
                       'points': 75,
                       'total_points': 75,
                       'rank': 1648468,
                       'rank_sort': 1759622,
                       'overall_rank': 1648468,
                       'percentile_rank': None,
                       'bank': 0,
                       'value': 1000,
                       'event_transfers': 0,
                       'event_transfers_cost': 0,
                       'points_on_bench': 12},
     'picks': [{'element': 275,
                'position': 1,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 405,
                'position': 2,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 131,
                'position': 3,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 228,
                'position': 4,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 12,
                'position': 5,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 308,
                'position': 6,
                'multiplier': 2,
                'is_captain': True,
                'is_vice_captain': False},
               {'element': 396,
                'position': 7,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 402,
                'position': 8,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 344,
                'position': 9,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 355,
                'position': 10,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': True},
               {'element': 119,
                'position': 11,
                'multiplier': 1,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 227,
                'position': 12,
                'multiplier': 0,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 326,
                'position': 13,
                'multiplier': 0,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 197,
                'position': 14,
                'multiplier': 0,
                'is_captain': False,
                'is_vice_captain': False},
               {'element': 407,
                'position': 15,
                'multiplier': 0,
                'is_captain': False,
                'is_vice_captain': False}]}]

# Append the manager league details to a json file
# with open('h2h_league_picks.json', 'w', encoding='utf-8') as f:
#       json.dump(v, f, ensure_ascii=False, indent=4)
data_file_contents = []
with open('h2h_league_picks.json') as data_file:
    data_file_contents = json.load(data_file)

print(data_file_contents)

# # parsed_json = json.loads(file_contents)
with open("h2h_league_picks.json", mode='w', encoding='utf-8') as f:
    print(f)
    entry = entry = {"league": v}
    data_file_contents.append(entry)
    json.dump(data_file_contents, f)
# Out:
# [{'active_chip': None, 'automatic_subs': [{'entry': 3532852, 'element_in': 275, 'element_out': 227, 'event': 1}], 'entry_history': {'event': 1, 'points': 75, 'total_points': 75, 'rank': 1648468, 'rank_sort': 1759622, 'overall_rank': 1648468, 'percentile_rank': None, 'bank': 0, 'value': 1000, 'event_transfers': 0, 'event_transfers_cost': 0, 'points_on_bench': 12}, 'picks': [{'element': 275, 'position': 1, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 405, 'position': 2, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 131, 'position': 3, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 228, 'position': 4, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 12, 'position': 5, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 308, 'position': 6, 'multiplier': 2, 'is_captain': True, 'is_vice_captain': False}, {'element': 396, 'position': 7, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 402, 'position': 8, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 344, 'position': 9, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 355, 'position': 10, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': True}, {'element': 119, 'position': 11, 'multiplier': 1, 'is_captain': False, 'is_vice_captain': False}, {'element': 227, 'position': 12, 'multiplier': 0, 'is_captain': False, 'is_vice_captain': False}, {'element': 326, 'position': 13, 'multiplier': 0, 'is_captain': False, 'is_vice_captain': False}, {'element': 197, 'position': 14, 'multiplier': 0, 'is_captain': False, 'is_vice_captain': False}, {'element': 407, 'position': 15, 'multiplier': 0, 'is_captain': False, 'is_vice_captain': False}]}, {'name': 'args.name', 'url': 'args.url'}]
# <_io.TextIOWrapper name='h2h_league_picks.json' mode='w' encoding='utf-8'>

# %%
picks.append({gw: gw_picks})
manager_picks.append({manager['manager_id']: picks})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 picks.append({gw: gw_picks})
#       2 manager_picks.append({manager['manager_id']: picks})
#
# NameError: name 'picks' is not defined

# %%
import requests
import json
import pandas as pd
import asyncio
import math

base_url = 'https://fantasy.premierleague.com/api/'


def get_transfers(league):
    # Get manager details
    general_info = requests.get(
        base_url + "leagues-h2h-matches/league/" + str(league) + "/").json()

    # For each manager id, get the the details
    # for id_ in manager_ids:
    manager_details_ = [{"manager_id": manager['entry_1_entry'], "player_name": manager['entry_1_player_name'],
                         "name": manager['entry_1_name']} for manager in general_info['results']]
    manager_details = list(
        {manager['manager_id']: manager for manager in manager_details_}.values())

    # For each manager, get their pick history
    manager_picks = []
    for manager in manager_details:
        # For leagues with teams, a virtual manager is include.
        # Check if a manager_id is 'None' and skip that manager
        if (manager['manager_id'] == None):
            continue

        picks = []
        for gw in range(1, 39):
            try:
                gw_picks = requests.get(
                    base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(gw) + "/picks/").json()
            except requests.exceptions.JSONDecodeError as jsonerror:
                print("JSONEconding Error: ", jsonerror, ", ",
                      gw, '=========> ', manager['manager_id'])
            except requests.exceptions.HTTPError as errh:
                print("Http Error:", errh)
            except requests.exceptions.ConnectionError as errc:
                print("Error Connecting:", errc)
            except requests.exceptions.Timeout as errt:
                print("Timeout Error:", errt)
            except requests.exceptions.RequestException as err:
                print("OOps: Something Else", err)

        picks = []
        for gw in range(1, 39):
            gw_picks = requests.get(
                base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(gw) + "/picks/").json()
            picks.append({gw: gw_picks})
        manager_picks.append({manager['manager_id']: picks})

    return {league: manager_picks}

# %%
# Get league ids between 2123000 and 2123881
league_ids = []
for i in range(2123000, 2123881):
    general_info = requests.get(
        base_url + "leagues-h2h-matches/league/" + str(i) + "/").json()
    # Check if the response contains a results list and it is not empty
    if ('results' in general_info and general_info['results']):
        league_ids.append(i)
print('leagues collected')
# league_history = [get_transfers(league) for league in league_ids]
# Out:
# leagues collected
#
#  Starting to get league details

# %%
league_ids
# Out:
# [2123002,
#  2123013,
#  2123014,
#  2123021,
#  2123034,
#  2123039,
#  2123043,
#  2123047,
#  2123049,
#  2123054,
#  2123062,
#  2123064,
#  2123067,
#  2123084,
#  2123085,
#  2123088,
#  2123091,
#  2123093,
#  2123095,
#  2123112,
#  2123126,
#  2123129,
#  2123144,
#  2123146,
#  2123149,
#  2123153,
#  2123162,
#  2123163,
#  2123164,
#  2123168,
#  2123169,
#  2123170,
#  2123176,
#  2123190,
#  2123207,
#  2123210,
#  2123211,
#  2123223,
#  2123232,
#  2123238,
#  2123244,
#  2123248,
#  2123250,
#  2123254,
#  2123255,
#  2123261,
#  2123262,
#  2123263,
#  2123267,
#  2123269,
#  2123271,
#  2123275,
#  2123290,
#  2123293,
#  2123314,
#  2123315,
#  2123329,
#  2123340,
#  2123349,
#  2123350,
#  2123355,
#  2123374,
#  2123377,
#  2123385,
#  2123386,
#  2123387,
#  2123389,
#  2123399,
#  2123412,
#  2123422,
#  2123423,
#  2123424,
#  2123431,
#  2123452,
#  2123457,
#  2123459,
#  2123467,
#  2123468,
#  2123469,
#  2123471,
#  2123472,
#  2123474,
#  2123483,
#  2123485,
#  2123510,
#  2123513,
#  2123525,
#  2123532,
#  2123539,
#  2123541,
#  2123546,
#  2123550,
#  2123554,
#  2123555,
#  2123557,
#  2123560,
#  2123561,
#  2123563,
#  2123580,
#  2123582,
#  2123589,
#  2123600,
#  2123602,
#  2123606,
#  2123619,
#  2123627,
#  2123628,
#  2123642,
#  2123644,
#  2123649,
#  2123652,
#  2123653,
#  2123658,
#  2123669,
#  2123675,
#  2123679,
#  2123699,
#  2123700,
#  2123705,
#  2123709,
#  2123710,
#  2123713,
#  2123717,
#  2123725,
#  2123733,
#  2123737,
#  2123743,
#  2123744,
#  2123755,
#  2123763,
#  2123770,
#  2123776,
#  2123777,
#  2123779,
#  2123780,
#  2123781,
#  2123782,
#  2123796,
#  2123805,
#  2123809,
#  2123818,
#  2123822,
#  2123824,
#  2123829,
#  2123830,
#  2123833,
#  2123834,
#  2123838,
#  2123860,
#  2123873,
#  2123877,
#  2123878,
#  2123880]

# %%
league_ids = [2123002, 2123013, 2123014, 2123021, 2123034, 2123039, 2123043, 2123047, 2123049, 2123054, 2123062, 2123064, 2123067, 2123084, 2123085, 2123088, 2123091, 2123093, 2123095, 2123112, 2123126, 2123129, 2123144, 2123146, 2123149, 2123153, 2123162, 2123163, 2123164, 2123168, 2123169, 2123170, 2123176, 2123190, 2123207, 2123210, 2123211, 2123223, 2123232, 2123238, 2123244, 2123248, 2123250, 2123254, 2123255, 2123261, 2123262, 2123263, 2123267, 2123269, 2123271, 2123275, 2123290, 2123293, 2123314, 2123315, 2123329, 2123340, 2123349, 2123350, 2123355, 2123374, 2123377, 2123385, 2123386, 2123387, 2123389, 2123399, 2123412, 2123422, 2123423, 2123424, 2123431, 2123452, 2123457, 2123459,
              2123467, 2123468, 2123469, 2123471, 2123472, 2123474, 2123483, 2123485, 2123510, 2123513, 2123525, 2123532, 2123539, 2123541, 2123546, 2123550, 2123554, 2123555, 2123557, 2123560, 2123561, 2123563, 2123580, 2123582, 2123589, 2123600, 2123602, 2123606, 2123619, 2123627, 2123628, 2123642, 2123644, 2123649, 2123652, 2123653, 2123658, 2123669, 2123675, 2123679, 2123699, 2123700, 2123705, 2123709, 2123710, 2123713, 2123717, 2123725, 2123733, 2123737, 2123743, 2123744, 2123755, 2123763, 2123770, 2123776, 2123777, 2123779, 2123780, 2123781, 2123782, 2123796, 2123805, 2123809, 2123818, 2123822, 2123824, 2123829, 2123830, 2123833, 2123834, 2123838, 2123860, 2123873, 2123877, 2123878, 2123880]

# %%
len(league_ids)
# Out:
# 153

# %%
for league in league_ids_:
    print('==> Fetching league transfer details for ', league)
    leagues_transfer_details = get_transfers(league)

    print('<== Completed fetching league transfer details for ', league)
    # Append the manager league details to a json file
    data_file_contents = []
    with open("./content/h2h_league_picks.json") as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("./content/h2h_league_picks.json", mode='w',  encoding='utf-8') as f:
        data_file_contents.append(leagues_transfer_details)
        json.dump(data_file_contents, f)

    # Log some details to show progress
    print(league, ':::::::::::',  round(
        (league_ids_.index(league)+1)/len(league_ids_)*100, 1), "%", " done")
# Out:
# Created the batch json file the leagues:  0
# ==> Fetching league transfer details for  2123064
# Created the batch json file the leagues:  1
# ==> Fetching league transfer details for  2123129
# Created the batch json file the leagues:  2
# ==> Fetching league transfer details for  2123170
# Created the batch json file the leagues:  3
# ==> Fetching league transfer details for  2123248
# Created the batch json file the leagues:  4
# ==> Fetching league transfer details for  2123275
# Created the batch json file the leagues:  5
# ==> Fetching league transfer details for  2123374
# Created the batch json file the leagues:  6
# ==> Fetching league transfer details for  2123424
# Created the batch json file the leagues:  7
# ==> Fetching league transfer details for  2123474
# Created the batch json file the leagues:  8
# ==> Fetching league transfer details for  2123550
# Created the batch json file the leagues:  9
# ==> Fetching league transfer details for  2123600
# Created the batch json file the leagues:  10
# ==> Fetching league transfer details for  2123653
# Created the batch json file the leagues:  11
# ==> Fetching league transfer details for  2123713
# Created the batch json file the leagues:  12
# ==> Fetching league transfer details for  2123776
# Created the batch json file the leagues:  13
# ==> Fetching league transfer details for  2123822
# Created the batch json file the leagues:  14
# ==> Fetching league transfer details for  2123878
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000023217310E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='fantasy.premierleague.com', port=443): Max retries exceeded with url: /api/leagues-h2h-matches/league/2123064/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023217310E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[9], line 73
#      71     await task13
#      72     await task14
# ---> 73 await main()
#
# Cell In[9], line 58, in main()
#      52 task14 = loop.create_task(fetch_data(id_chunks[14], 14))
#      53 # await asyncio.gather(fetch_data(id_chunks[0], 0), fetch_data(id_chunks[1], 1), fetch_data(id_chunks[2], 2), fetch_data(id_chunks[3], 3), fetch_data(id_chunks[4], 4), fetch_data(id_chunks[5], 5),
#      54 #                      fetch_data(id_chunks[6], 6), fetch_data(id_chunks[7], 7), fetch_data(id_chunks[8], 8), fetch_data(
#      55 #                          id_chunks[9], 9), fetch_data(id_chunks[10], 10), fetch_data(id_chunks[11], 11),
#      56 #                      fetch_data(id_chunks[12], 12), fetch_data(id_chunks[13], 13), fetch_data(id_chunks[14], 14))
# ---> 58 await task0
#      59 await task1
#      60 await task2
#
# Cell In[9], line 14, in fetch_data(league_id_list, count)
#      12 for league in league_id_list:
#      13     print('==> Fetching league transfer details for ', league)
# ---> 14     leagues_transfer_details = await get_transfers(league)
#      16     print('<== Completed fetching league transfer details for ', league)
#      17     # Append the manager league details to a json file
#
# Cell In[2], line 12, in get_transfers(league)
#      10 async def get_transfers(league):
#      11     # Get manager details
# ---> 12     general_info = requests.get(
#      13         base_url + "leagues-h2h-matches/league/" + str(league) + "/").json()
#      15     # For each manager id, get the the details
#      16     # for id_ in manager_ids:
#      17     manager_details_ = [{"manager_id": manager['entry_1_entry'], "player_name": manager['entry_1_player_name'],
#      18                          "name": manager['entry_1_name']} for manager in general_info['results']]
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='fantasy.premierleague.com', port=443): Max retries exceeded with url: /api/leagues-h2h-matches/league/2123064/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023217310E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
import math
data = [2123002, 2123013, 2123014, 2123021, 2123034, 2123039,
        2123043, 2123047, 2123049, 2123054, 2123062]  # 11/0.1
size = math.ceil(len(data)/10)

chunks = [data[i*size:(i+1)*size] for i in range(10)]

chunks
# Out:
# [[2123002, 2123013],
#  [2123014, 2123021],
#  [2123034, 2123039],
#  [2123043, 2123047],
#  [2123049, 2123054],
#  [2123062],
#  [],
#  [],
#  [],
#  []]

# %%
for i in chunks:
    if i:
        print(i)
# Out:
# [2123002, 2123013]
# [2123014, 2123021]
# [2123034, 2123039]
# [2123043, 2123047]
# [2123049, 2123054]
# [2123062]

# %%
print('\n Starting to get league details')
for league in league_ids_:
    print('==> Fetching league transfer details for ', league)
    leagues_transfer_details = get_transfers(league)

    print('<== Completed fetching league transfer details for ', league)
    # Append the manager league details to a json file
    data_file_contents = []
    with open('./content/h2h_league_picks.json') as data_file:
        data_file_contents = json.load(data_file)

    # # parsed_json = json.loads(file_contents)
    with open("./content/h2h_league_picks.json", mode='w', encoding='utf-8') as f:
        data_file_contents.append(leagues_transfer_details)
        json.dump(data_file_contents, f)

    # Log some details to show progress
    print(league, '::::::::::: ', round(
        (league_ids.index(league)+1)/len(league_ids)*100, 1), "%", " done")
# Out:
#  Starting to get league details
# ==> Fetching league transfer details for  2123054
# <== Completed fetching league transfer details for  2123054
# 2123054 :::::::::::  6.5 %  done
# ==> Fetching league transfer details for  2123062
# <== Completed fetching league transfer details for  2123062
# 2123062 :::::::::::  7.2 %  done
# ==> Fetching league transfer details for  2123064
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\ssl.py:1383, in SSLSocket.do_handshake(self, block)
#    1382         self.settimeout(None)
# -> 1383     self._sslobj.do_handshake()
#    1384 finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\ssl.py:1383, in SSLSocket.do_handshake(self, block)
#    1382         self.settimeout(None)
# -> 1383     self._sslobj.do_handshake()
#    1384 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[121], line 4
#       2 for league in league_ids_:
#       3     print('==> Fetching league transfer details for ', league)
# ----> 4     leagues_transfer_details = get_transfers(league)
#       6     print('<== Completed fetching league transfer details for ', league)
#       7     # Append the manager league details to a json file
#
# Cell In[104], line 47, in get_transfers(league)
#      45 picks = []
#      46 for gw in range(1, 39):
# ---> 47     gw_picks = requests.get(
#      48         base_url + "entry/" + str(manager['manager_id']) + "/event/" + str(gw) + "/picks/").json()
#      49     picks.append({gw: gw_picks})
#      50 manager_picks.append({manager['manager_id']: picks})
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Ilyas\anaconda3\envs\FPL\Lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
if []:
    print('hey')
# Out:
#   Cell In[67], line 1
#     if ![]:
#        ^
# SyntaxError: invalid syntax

# %%
# Out:
# Created the batch json file the leagues:  0
# ==> Fetching league transfer details for  2123002
# Created the batch json file the leagues:  1
# ==> Fetching league transfer details for  2123062
# Created the batch json file the leagues:  2
# Created the batch json file the leagues:  3
# Created the batch json file the leagues:  4
# Created the batch json file the leagues:  5
# Created the batch json file the leagues:  6
# Created the batch json file the leagues:  7
# Created the batch json file the leagues:  8
# Created the batch json file the leagues:  9
# Created the batch json file the leagues:  10
# Created the batch json file the leagues:  11
# Created the batch json file the leagues:  12
# Created the batch json file the leagues:  13
# Created the batch json file the leagues:  14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 43
#      38     id_chunks = [data[i*size:(i+1)*size] for i in range(15)]
#      39     await asyncio.gather(fetch_data(id_chunks[0], 0), fetch_data(id_chunks[1],1), fetch_data(id_chunks[2],2), fetch_data(id_chunks[3],3), fetch_data(id_chunks[4],4), fetch_data(id_chunks[5],5),
#      40         fetch_data(id_chunks[6],6), fetch_data(id_chunks[7],7), fetch_data(id_chunks[8],8), fetch_data(id_chunks[9],9), fetch_data(id_chunks[10],10), fetch_data(id_chunks[11],11),
#      41         fetch_data(id_chunks[12],12), fetch_data(id_chunks[13],13), fetch_data(id_chunks[14],14))
# ---> 43 await main()
#
# Cell In[81], line 39, in main()
#      36 size = math.ceil(len(league_ids_)/15)
#      38 id_chunks = [data[i*size:(i+1)*size] for i in range(15)]
# ---> 39 await asyncio.gather(fetch_data(id_chunks[0], 0), fetch_data(id_chunks[1],1), fetch_data(id_chunks[2],2), fetch_data(id_chunks[3],3), fetch_data(id_chunks[4],4), fetch_data(id_chunks[5],5),
#      40     fetch_data(id_chunks[6],6), fetch_data(id_chunks[7],7), fetch_data(id_chunks[8],8), fetch_data(id_chunks[9],9), fetch_data(id_chunks[10],10), fetch_data(id_chunks[11],11),
#      41     fetch_data(id_chunks[12],12), fetch_data(id_chunks[13],13), fetch_data(id_chunks[14],14))
#
# Cell In[81], line 18, in fetch_data(league_id_list, count)
#      16 for league in league_id_list:
#      17     print('==> Fetching league transfer details for ', league)
# ---> 18     leagues_transfer_details = get_transfers(league)
#      20     print('<== Completed fetching league transfer details for ', league)
#      21     # Append the manager league details to a json file
#
# NameError: name 'get_transfers' is not defined

# %%
import json
with open("./h2h_league_picks_62378.json", mode='w', encoding='utf-8') as f:
    # data_file_contents.append(leagues_transfer_details)
    json.dump([], f)
    print('opened')

with open("./h2h_league_picks_62378.json", mode='r+', encoding='utf-8') as f:
    # data_file_contents.append(leagues_transfer_details)
    json.load(f)
    print('opened')

[
    [leagues => ]
]
# Out:
# opened
# opened
